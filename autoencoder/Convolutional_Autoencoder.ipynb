# %% [markdown]
# # Convolutional Autoencoder
#
# Sticking with the MNIST dataset, let's improve our autoencoder's performance using convolutional layers. Again, loading modules and the data.

# %%
# %matplotlib inline

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data', validation_size=0)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
img = mnist.train.images[2]
plt.imshow(img.reshape((28, 28)), cmap='Greys_r')

# %% [markdown]
# ## Network Architecture
#
# The encoder part of the network will be a typical convolutional pyramid. Each convolutional layer will be followed by a max-pooling layer to reduce the dimensions of the layers. The decoder though might be something new to you. The decoder needs to convert from a narrow representation to a wide reconstructed image. For example, the representation could be a 4x4x8 max-pool layer. This is the output of the encoder, but also the input to the decoder. We want to get a 28x28x1 image out from the decoder so we need to work our way back up from the narrow decoder input layer. A schematic of the network is shown below.
#
# ![Convolutional Autoencoder](assets/convolutional_autoencoder.png)
#
# Here our final encoder layer has size 4x4x8 = 128. The original images have size 28x28 = 784, so the encoded vector is roughly 16% the size of the original image. These are just suggested sizes for each of the layers. Feel free to change the depths and sizes, but remember our goal here is to find a small representation of the input data.
#
# ### What's going on with the decoder
#
# Okay, so the decoder has these "Upsample" layers that you might not have seen before. First off, I'll discuss a bit what these layers *aren't*. Usually, you'll see **deconvolutional** layers used to increase the width and height of the layers. They work almost exactly the same as convolutional layers, but it reverse. A stride in the input layer results in a larger stride in the deconvolutional layer. For example, if you have a 3x3 kernel, a 3x3 patch in the input layer will be reduced to one unit in a convolutional layer. Comparatively, one unit in the input layer will be expanded to a 3x3 path in a deconvolutional layer. Deconvolution is often called "transpose convolution" which is what you'll find with the TensorFlow API, with [`tf.nn.conv2d_transpose`](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d_transpose).
#
# However, deconvolutional layers can lead to artifacts in the final images, such as checkerboard patterns. This is due to overlap in the kernels which can be avoided by setting the stride and kernel size equal. In [this Distill article](http://distill.pub/2016/deconv-checkerboard/) from Augustus Odena, *et al*, the authors show that these checkerboard artifacts can be avoided by resizing the layers using nearest neighbor or bilinear interpolation (upsampling) followed by a convolutional layer. In TensorFlow, this is easily done with [`tf.image.resize_images`](https://www.tensorflow.org/versions/r1.1/api_docs/python/tf/image/resize_images), followed by a convolution. Be sure to read the Distill article to get a better understanding of deconvolutional layers and why we're using upsampling.
#
# > **Exercise:** Build the network shown above. Remember that a convolutional layer with strides of 1 and 'same' padding won't reduce the height and width. That is, if the input is 28x28 and the convolution layer has stride = 1 and 'same' padding, the convolutional layer will also be 28x28. The max-pool layers are used the reduce the width and height. A stride of 2 will reduce the size by 2. Odena *et al* claim that nearest neighbor interpolation works best for the upsampling, so make sure to include that as a parameter in `tf.image.resize_images` or use [`tf.image.resize_nearest_neighbor`]( `https://www.tensorflow.org/api_docs/python/tf/image/resize_nearest_neighbor).

# %%
learning_rate = 0.001
inputs_ = tf.placeholder(tf.float32, shape=[None, 28,28,1], name="input_images")
targets_ = tf.placeholder(tf.float32, shape=[None, 28,28,1], name="target_images")

### Encoder
conv1 = tf.layers.conv2d(inputs_, filters=16, kernel_size=(4,4), strides=(1, 1), padding='SAME', activation=tf.nn.relu)
# Now 28x28x16

maxpool1 = tf.nn.max_pool(conv1, ksize=[1,2,2,1], strides=[1,2,2,1], padding="SAME")
# Now 14x14x16

conv2 = tf.layers.conv2d(maxpool1, filters=8, kernel_size=(4,4), strides=(1, 1), padding='SAME', activation=tf.nn.relu)
# Now 14x14x8

maxpool2 = tf.nn.max_pool(conv2, ksize=[1,2,2,1], strides=[1,2,2,1], padding="SAME")
# Now 7x7x8

conv3 = tf.layers.conv2d(maxpool2, filters=8, kernel_size=(4,4), strides=(1, 1), padding='SAME', activation=tf.nn.relu)
# Now 7x7x8

encoded = tf.nn.max_pool(conv3, ksize=[1,2,2,1], strides=[1,2,2,1], padding="SAME")
# Now 4x4x8

### Decoder
upsample1 = tf.image.resize_nearest_neighbor(encoded, [7, 7])
# Now 7x7x8

conv4 = tf.layers.conv2d(upsample1, filters=8, kernel_size=(4,4), strides=(1, 1), padding='SAME', activation=tf.nn.relu)
# Now 7x7x8

upsample2 = tf.image.resize_nearest_neighbor(conv4, [14, 14])
# Now 14x14x8

conv5 = tf.layers.conv2d(upsample2, filters=8, kernel_size=(4,4), strides=(1, 1), padding='SAME', activation=tf.nn.relu)
# Now 14x14x8

upsample3 = tf.image.resize_nearest_neighbor(conv5, [28, 28])
# Now 28x28x8

conv6 = tf.layers.conv2d(upsample3, filters=16, kernel_size=(4,4), strides=(1, 1), padding='SAME', activation=tf.nn.relu)
# Now 28x28x16

logits = tf.layers.conv2d(conv6, filters=1, kernel_size=(4,4), strides=(1, 1), padding='SAME', activation=None)
# Now 28x28x1

# Pass logits through sigmoid to get reconstructed image
decoded = tf.nn.sigmoid(logits)

# Pass logits through sigmoid and calculate the cross-entropy loss
loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=targets_, logits=logits)

# Get cost and define the optimizer
cost = tf.reduce_mean(loss)
opt = tf.train.AdamOptimizer(learning_rate).minimize(cost)

# %% [markdown]
# ## Training
#
# As before, here wi'll train the network. Instead of flattening the images though, we can pass them in as 28x28x1 arrays.

# %%
sess = tf.Session()

# %%
epochs = 20
batch_size = 200
sess.run(tf.global_variables_initializer())
for e in range(epochs):
    for ii in range(mnist.train.num_examples//batch_size):
        batch = mnist.train.next_batch(batch_size)
        imgs = batch[0].reshape((-1, 28, 28, 1))
        batch_cost, _ = sess.run([cost, opt], feed_dict={inputs_: imgs,
                                                         targets_: imgs})

        print("Epoch: {}/{}...".format(e+1, epochs),
              "Training loss: {:.4f}".format(batch_cost))
# Out:
# Epoch: 1/20... Training loss: 0.6982
# Epoch: 1/20... Training loss: 0.6928
# Epoch: 1/20... Training loss: 0.6893
# Epoch: 1/20... Training loss: 0.6863
# Epoch: 1/20... Training loss: 0.6822
# Epoch: 1/20... Training loss: 0.6757
# Epoch: 1/20... Training loss: 0.6699
# Epoch: 1/20... Training loss: 0.6550
# Epoch: 1/20... Training loss: 0.6378
# Epoch: 1/20... Training loss: 0.6205
# Epoch: 1/20... Training loss: 0.5961
# Epoch: 1/20... Training loss: 0.5635
# Epoch: 1/20... Training loss: 0.5368
# Epoch: 1/20... Training loss: 0.5153
# Epoch: 1/20... Training loss: 0.5168
# Epoch: 1/20... Training loss: 0.5083
# Epoch: 1/20... Training loss: 0.5183
# Epoch: 1/20... Training loss: 0.5119
# Epoch: 1/20... Training loss: 0.5388
# Epoch: 1/20... Training loss: 0.4915
# Epoch: 1/20... Training loss: 0.4848
# Epoch: 1/20... Training loss: 0.4804
# Epoch: 1/20... Training loss: 0.4871
# Epoch: 1/20... Training loss: 0.5011
# Epoch: 1/20... Training loss: 0.4845
# Epoch: 1/20... Training loss: 0.4856
# Epoch: 1/20... Training loss: 0.4852
# Epoch: 1/20... Training loss: 0.4773
# Epoch: 1/20... Training loss: 0.4611
# Epoch: 1/20... Training loss: 0.4575
# Epoch: 1/20... Training loss: 0.4860
# Epoch: 1/20... Training loss: 0.4527
# Epoch: 1/20... Training loss: 0.4258
# Epoch: 1/20... Training loss: 0.4002
# Epoch: 1/20... Training loss: 0.4101
# Epoch: 1/20... Training loss: 0.3891
# Epoch: 1/20... Training loss: 0.3653
# Epoch: 1/20... Training loss: 0.3593
# Epoch: 1/20... Training loss: 0.3662
# Epoch: 1/20... Training loss: 0.3854
# Epoch: 1/20... Training loss: 0.3550
# Epoch: 1/20... Training loss: 0.3484
# Epoch: 1/20... Training loss: 0.3569
# Epoch: 1/20... Training loss: 0.3404
# Epoch: 1/20... Training loss: 0.3120
# Epoch: 1/20... Training loss: 0.2995
# Epoch: 1/20... Training loss: 0.2964
# Epoch: 1/20... Training loss: 0.3045
# Epoch: 1/20... Training loss: 0.2925
# Epoch: 1/20... Training loss: 0.2836
# Epoch: 1/20... Training loss: 0.2712
# Epoch: 1/20... Training loss: 0.3059
# Epoch: 1/20... Training loss: 0.2790
# Epoch: 1/20... Training loss: 0.2567
# Epoch: 1/20... Training loss: 0.2598
# Epoch: 1/20... Training loss: 0.2637
# Epoch: 1/20... Training loss: 0.2516
# Epoch: 1/20... Training loss: 0.2432
# Epoch: 1/20... Training loss: 0.2383
# Epoch: 1/20... Training loss: 0.2347
# Epoch: 1/20... Training loss: 0.2444
# Epoch: 1/20... Training loss: 0.2480
# Epoch: 1/20... Training loss: 0.2506
# Epoch: 1/20... Training loss: 0.2479
# Epoch: 1/20... Training loss: 0.2380
# Epoch: 1/20... Training loss: 0.2420
# Epoch: 1/20... Training loss: 0.2391
# Epoch: 1/20... Training loss: 0.2449
# Epoch: 1/20... Training loss: 0.2231
# Epoch: 1/20... Training loss: 0.2291
# Epoch: 1/20... Training loss: 0.2443
# Epoch: 1/20... Training loss: 0.2333
# Epoch: 1/20... Training loss: 0.2239
# Epoch: 1/20... Training loss: 0.2238
# Epoch: 1/20... Training loss: 0.2181
# Epoch: 1/20... Training loss: 0.2188
# Epoch: 1/20... Training loss: 0.2142
# Epoch: 1/20... Training loss: 0.2144
# Epoch: 1/20... Training loss: 0.2199
# Epoch: 1/20... Training loss: 0.2148
# Epoch: 1/20... Training loss: 0.2185
# Epoch: 1/20... Training loss: 0.2131
# Epoch: 1/20... Training loss: 0.2158
# Epoch: 1/20... Training loss: 0.2129
# Epoch: 1/20... Training loss: 0.2103
# Epoch: 1/20... Training loss: 0.2183
# Epoch: 1/20... Training loss: 0.2229
# Epoch: 1/20... Training loss: 0.2135
# Epoch: 1/20... Training loss: 0.2042
# Epoch: 1/20... Training loss: 0.2009
# Epoch: 1/20... Training loss: 0.2009
# Epoch: 1/20... Training loss: 0.2002
# Epoch: 1/20... Training loss: 0.2086
# Epoch: 1/20... Training loss: 0.2122
# Epoch: 1/20... Training loss: 0.2068
# Epoch: 1/20... Training loss: 0.2004
# Epoch: 1/20... Training loss: 0.2218
# Epoch: 1/20... Training loss: 0.2105
# Epoch: 1/20... Training loss: 0.2140
# Epoch: 1/20... Training loss: 0.2206
# Epoch: 1/20... Training loss: 0.2114
# Epoch: 1/20... Training loss: 0.2053
# Epoch: 1/20... Training loss: 0.2019
# Epoch: 1/20... Training loss: 0.1995
# Epoch: 1/20... Training loss: 0.1987
# Epoch: 1/20... Training loss: 0.2007
# Epoch: 1/20... Training loss: 0.2146
# Epoch: 1/20... Training loss: 0.2047
# Epoch: 1/20... Training loss: 0.1974
# Epoch: 1/20... Training loss: 0.2061
# Epoch: 1/20... Training loss: 0.2142
# Epoch: 1/20... Training loss: 0.2014
# Epoch: 1/20... Training loss: 0.1933
# Epoch: 1/20... Training loss: 0.1987
# Epoch: 1/20... Training loss: 0.1989
# Epoch: 1/20... Training loss: 0.2012
# Epoch: 1/20... Training loss: 0.1907
# Epoch: 1/20... Training loss: 0.1926
# Epoch: 1/20... Training loss: 0.2022
# Epoch: 1/20... Training loss: 0.2037
# Epoch: 1/20... Training loss: 0.1800
# Epoch: 1/20... Training loss: 0.1861
# Epoch: 1/20... Training loss: 0.1993
# Epoch: 1/20... Training loss: 0.1849
# Epoch: 1/20... Training loss: 0.1768
# Epoch: 1/20... Training loss: 0.1927
# Epoch: 1/20... Training loss: 0.1995
# Epoch: 1/20... Training loss: 0.1876
# Epoch: 1/20... Training loss: 0.1912
# Epoch: 1/20... Training loss: 0.1835
# Epoch: 1/20... Training loss: 0.1838
# Epoch: 1/20... Training loss: 0.1821
# Epoch: 1/20... Training loss: 0.1866
# Epoch: 1/20... Training loss: 0.1895
# Epoch: 1/20... Training loss: 0.1807
# Epoch: 1/20... Training loss: 0.1993
# Epoch: 1/20... Training loss: 0.1973
# Epoch: 1/20... Training loss: 0.1919
# Epoch: 1/20... Training loss: 0.1905
# Epoch: 1/20... Training loss: 0.1892
# Epoch: 1/20... Training loss: 0.1847
# Epoch: 1/20... Training loss: 0.1869
# Epoch: 1/20... Training loss: 0.1853
# Epoch: 1/20... Training loss: 0.1808
# Epoch: 1/20... Training loss: 0.1902
# Epoch: 1/20... Training loss: 0.1953
# Epoch: 1/20... Training loss: 0.1862
# Epoch: 1/20... Training loss: 0.1812
# Epoch: 1/20... Training loss: 0.1780
# Epoch: 1/20... Training loss: 0.1688
# Epoch: 1/20... Training loss: 0.1774
# Epoch: 1/20... Training loss: 0.1855
# Epoch: 1/20... Training loss: 0.1808
# Epoch: 1/20... Training loss: 0.1776
# Epoch: 1/20... Training loss: 0.1726
# Epoch: 1/20... Training loss: 0.1808
# Epoch: 1/20... Training loss: 0.1723
# Epoch: 1/20... Training loss: 0.1796
# Epoch: 1/20... Training loss: 0.1805
# Epoch: 1/20... Training loss: 0.1759
# Epoch: 1/20... Training loss: 0.1765
# Epoch: 1/20... Training loss: 0.1725
# Epoch: 1/20... Training loss: 0.1749
# Epoch: 1/20... Training loss: 0.1853
# Epoch: 1/20... Training loss: 0.1773
# Epoch: 1/20... Training loss: 0.1712
# Epoch: 1/20... Training loss: 0.1781
# Epoch: 1/20... Training loss: 0.1746
# Epoch: 1/20... Training loss: 0.1660
# Epoch: 1/20... Training loss: 0.1646
# Epoch: 1/20... Training loss: 0.1722
# Epoch: 1/20... Training loss: 0.1735
# Epoch: 1/20... Training loss: 0.1762
# Epoch: 1/20... Training loss: 0.1712
# Epoch: 1/20... Training loss: 0.1651
# Epoch: 1/20... Training loss: 0.1732
# Epoch: 1/20... Training loss: 0.1668
# Epoch: 1/20... Training loss: 0.1747
# Epoch: 1/20... Training loss: 0.1762
# Epoch: 1/20... Training loss: 0.1757
# Epoch: 1/20... Training loss: 0.1738
# Epoch: 1/20... Training loss: 0.1796
# Epoch: 1/20... Training loss: 0.1758
# Epoch: 1/20... Training loss: 0.1752
# Epoch: 1/20... Training loss: 0.1694
# Epoch: 1/20... Training loss: 0.1590
# Epoch: 1/20... Training loss: 0.1657
# Epoch: 1/20... Training loss: 0.1753
# Epoch: 1/20... Training loss: 0.1784
# Epoch: 1/20... Training loss: 0.1661
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-ee1b2a582e4e> in <module>()
#       7         imgs = batch[0].reshape((-1, 28, 28, 1))
#       8         batch_cost, _ = sess.run([cost, opt], feed_dict={inputs_: imgs,
# ----> 9                                                          targets_: imgs})
#      10
#      11         print("Epoch: {}/{}...".format(e+1, epochs),
#
# /Users/thalles/anaconda/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/thalles/anaconda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /Users/thalles/anaconda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/thalles/anaconda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /Users/thalles/anaconda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(20,4))
in_imgs = mnist.test.images[:10]
reconstructed = sess.run(decoded, feed_dict={inputs_: in_imgs.reshape((10, 28, 28, 1))})

for images, row in zip([in_imgs, reconstructed], axes):
    for img, ax in zip(images, row):
        ax.imshow(img.reshape((28, 28)), cmap='Greys_r')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)


fig.tight_layout(pad=0.1)

# %%
sess.close()

# %% [markdown]
# ## Denoising
#
# As I've mentioned before, autoencoders like the ones you've built so far aren't too useful in practive. However, they can be used to denoise images quite successfully just by training the network on noisy images. We can create the noisy images ourselves by adding Gaussian noise to the training images, then clipping the values to be between 0 and 1. We'll use noisy images as input and the original, clean images as targets. Here's an example of the noisy images I generated and the denoised images.
#
# ![Denoising autoencoder](assets/denoising.png)
#
#
# Since this is a harder problem for the network, we'll want to use deeper convolutional layers here, more feature maps. I suggest something like 32-32-16 for the depths of the convolutional layers in the encoder, and the same depths going backward through the decoder. Otherwise the architecture is the same as before.
#
# > **Exercise:** Build the network for the denoising autoencoder. It's the same as before, but with deeper layers. I suggest 32-32-16 for the depths, but you can play with these numbers, or add more layers.

# %%
learning_rate = 0.001
inputs_ = tf.placeholder(tf.float32, (None, 28, 28, 1), name='inputs')
targets_ = tf.placeholder(tf.float32, (None, 28, 28, 1), name='targets')

### Encoder
conv1 = 
# Now 28x28x32
maxpool1 = 
# Now 14x14x32
conv2 = 
# Now 14x14x32
maxpool2 = 
# Now 7x7x32
conv3 = 
# Now 7x7x16
encoded = 
# Now 4x4x16

### Decoder
upsample1 = 
# Now 7x7x16
conv4 = 
# Now 7x7x16
upsample2 = 
# Now 14x14x16
conv5 = 
# Now 14x14x32
upsample3 = 
# Now 28x28x32
conv6 = 
# Now 28x28x32

logits = 
#Now 28x28x1

# Pass logits through sigmoid to get reconstructed image
decoded =

# Pass logits through sigmoid and calculate the cross-entropy loss
loss = 

# Get cost and define the optimizer
cost = tf.reduce_mean(loss)
opt = tf.train.AdamOptimizer(learning_rate).minimize(cost)

# %%
sess = tf.Session()

# %%
epochs = 100
batch_size = 200
# Set's how much noise we're adding to the MNIST images
noise_factor = 0.5
sess.run(tf.global_variables_initializer())
for e in range(epochs):
    for ii in range(mnist.train.num_examples//batch_size):
        batch = mnist.train.next_batch(batch_size)
        # Get images from the batch
        imgs = batch[0].reshape((-1, 28, 28, 1))
        
        # Add random noise to the input images
        noisy_imgs = imgs + noise_factor * np.random.randn(*imgs.shape)
        # Clip the images to be between 0 and 1
        noisy_imgs = np.clip(noisy_imgs, 0., 1.)
        
        # Noisy images as inputs, original images as targets
        batch_cost, _ = sess.run([cost, opt], feed_dict={inputs_: noisy_imgs,
                                                         targets_: imgs})

        print("Epoch: {}/{}...".format(e+1, epochs),
              "Training loss: {:.4f}".format(batch_cost))

# %% [markdown]
# ## Checking out the performance
#
# Here I'm adding noise to the test images and passing them through the autoencoder. It does a suprisingly great job of removing the noise, even though it's sometimes difficult to tell what the original number is.

# %%
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(20,4))
in_imgs = mnist.test.images[:10]
noisy_imgs = in_imgs + noise_factor * np.random.randn(*in_imgs.shape)
noisy_imgs = np.clip(noisy_imgs, 0., 1.)

reconstructed = sess.run(decoded, feed_dict={inputs_: noisy_imgs.reshape((10, 28, 28, 1))})

for images, row in zip([noisy_imgs, reconstructed], axes):
    for img, ax in zip(images, row):
        ax.imshow(img.reshape((28, 28)), cmap='Greys_r')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

fig.tight_layout(pad=0.1)
