# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:28, 1.12MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter

int_word_cnts = Counter(int_words)

# %%
## Your code here
import math
import random

t = 1e-5
total_cnt = float(sum([cnt for _,cnt in int_word_cnts.most_common()]))
word_probs = {word_id: 1-math.sqrt(t/(cnt/total_cnt)) for word_id,cnt in int_word_cnts.most_common()}
train_words = [word_id for word_id in int_words if random.random() < (1-word_probs[word_id])]
len(train_words)
# Out:
# 4627711

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    rnd_window_size = random.randint(1, window_size+1)
    min_idx = max(0, idx-window_size)
    max_idx = min(len(words), idx+window_size+1)
    return list(set(words[min_idx: idx] + words[(idx+1): max_idx]))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None], name='inputs')
    labels = tf.placeholder(tf.int32, shape=[None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed, 
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6103 0.6640 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5964 0.6163 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4723 0.6626 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5298 0.5728 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4703 0.5961 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4720 0.6044 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5104 0.5835 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.4739 0.5997 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.3657 0.5345 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3759 0.5499 sec/batch
# Nearest to when: arm, uruguayan, imperatoribus, fabricated, tarleton, hands, iast, aelius,
# Nearest to were: summary, gaelic, nitrite, pwn, rumpus, dulles, churned, lie,
# Nearest to zero: sole, payment, lark, axons, adp, tracked, carloman, possess,
# Nearest to about: stating, benefactors, ferrite, whitey, apatosaurus, vegans, sassanid, addressing,
# Nearest to from: codifying, invaded, evangelist, natural, lollard, frutti, longing, thebes,
# Nearest to nine: whole, sitting, drawer, indictees, unaccustomed, ailuropoda, risch, frank,
# Nearest to his: antennas, desi, sergey, altenberg, however, ito, boogaloo, tunic,
# Nearest to five: harald, minas, mortally, monomorphism, umm, bengals, influential, ladykillers,
# Nearest to prince: zoomed, xie, parachutes, roi, unload, disdain, stave, lammas,
# Nearest to rise: sky, az, deflate, micron, ermey, salamanca, administers, cafiero,
# Nearest to test: reliance, smil, mmol, baptist, september, humour, bytes, pricking,
# Nearest to operations: distinct, memorandum, art, il, restatement, match, ecusa, declared,
# Nearest to governor: geo, fraud, privatization, bassas, qimei, tyrone, united, sindarin,
# Nearest to mean: interesting, maillol, fick, oup, mehmet, platz, pisan, wet,
# Nearest to professional: evaded, competing, helmed, ingesting, hb, signage, mediators, cheat,
# Nearest to instance: faithful, isuzu, casinos, orlogsflag, hippocampus, zucchini, emesa, nothing,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.3631 0.6076 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.2840 0.4929 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.1906 0.5484 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.1495 0.7014 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.0536 0.6376 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.0358 0.6013 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.9636 0.5950 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.9713 0.5709 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9070 0.5463 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9087 0.5515 sec/batch
# Nearest to when: arm, hands, uruguayan, fabricated, imperatoribus, park, desire, distances,
# Nearest to were: summary, gaelic, lie, nitrite, angeles, xerox, outbursts, pwn,
# Nearest to zero: payment, sole, possess, tracked, italian, apportioned, lark, carloman,
# Nearest to about: stating, addressing, ferrite, vegans, benefactors, whitey, sassanid, continuing,
# Nearest to from: executives, codifying, invaded, partition, own, longing, regardless, natural,
# Nearest to nine: frank, briefly, drawer, indictees, lock, embracing, brigade, whole,
# Nearest to his: antennas, desi, however, sergey, protested, playing, altenberg, scores,
# Nearest to five: influential, mortally, harald, bengals, minas, females, monomorphism, bets,
# Nearest to prince: zoomed, parachutes, unload, stave, xie, disdain, forgiving, roi,
# Nearest to rise: sky, az, advantage, administers, p, ermey, gorbachev, deflate,
# Nearest to test: reliance, september, smil, humour, side, baptist, mmol, bytes,
# Nearest to operations: distinct, art, il, match, declared, restatement, enter, memorandum,
# Nearest to governor: privatization, fraud, united, geo, bassas, estonian, saintly, elsewhere,
# Nearest to mean: interesting, warship, fick, wet, maillol, recipient, oup, lines,
# Nearest to professional: competing, helmed, afford, cheat, evaded, normal, charles, ensure,
# Nearest to instance: faithful, nothing, embedded, composition, cutting, orlogsflag, lowell, surveyor,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.8568 0.5748 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8610 0.6654 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8211 0.6229 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8416 0.6306 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7737 0.6153 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.7847 0.5625 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7608 0.6633 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7612 0.8018 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7703 0.8940 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7642 0.6915 sec/batch
# Nearest to when: arm, hands, uruguayan, fabricated, tasmania, gypsum, legalistic, imperatoribus,
# Nearest to were: gaelic, summary, nitrite, lie, reconstruct, pwn, rumpus, morphine,
# Nearest to zero: payment, sole, tracked, ubiquitous, adp, italian, apportioned, possess,
# Nearest to about: stating, benefactors, whitey, addressing, vegans, sassanid, ferrite, obese,
# Nearest to from: codifying, executives, invaded, lollard, partition, messerschmitt, finalised, portfolio,
# Nearest to nine: frank, brigade, greg, turkmenistan, coyne, unaccustomed, lock, drawer,
# Nearest to his: antennas, desi, sergey, however, ito, tunic, alternativa, protested,
# Nearest to five: mortally, influential, ramifications, minas, relatedness, harald, geocities, brassiere,
# Nearest to prince: zoomed, parachutes, roi, stave, unload, xie, forgiving, antiquated,
# Nearest to rise: sky, az, deflate, administers, ermey, salamanca, gorbachev, advantage,
# Nearest to test: reliance, smil, baptist, bytes, mmol, hillside, side, september,
# Nearest to operations: distinct, art, il, memorandum, restatement, idi, match, finely,
# Nearest to governor: privatization, estonian, united, geo, polynesia, fraud, saintly, deflected,
# Nearest to mean: interesting, fick, warship, oup, maillol, recipient, installation, wet,
# Nearest to professional: competing, evaded, helmed, cheat, ingesting, afford, freeman, bitter,
# Nearest to instance: faithful, nothing, cutting, isuzu, hippocampus, orlogsflag, composition, embedded,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7785 0.6639 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7168 0.6373 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7134 0.6460 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6877 0.9199 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7324 0.6115 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6662 0.6206 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6778 0.6035 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7425 0.6362 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6969 0.5711 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6506 0.6237 sec/batch
# Nearest to when: arm, uruguayan, fabricated, hands, legalistic, indie, inglewood, imperatoribus,
# Nearest to were: rumpus, pwn, reconstruct, gaelic, summary, nitrite, toothbrush, dulles,
# Nearest to zero: payment, adp, nine, million, italian, sole, deaths, five,
# Nearest to about: addressing, benefactors, stating, apatosaurus, whitey, obese, incompleteness, vegans,
# Nearest to from: codifying, invaded, messerschmitt, partition, lollard, executives, hermetic, finalised,
# Nearest to nine: frank, chemist, turkmenistan, greg, brigade, zero, aiken, lithuanian,
# Nearest to his: sergey, antennas, desi, alternativa, tunic, ito, surreptitiously, famed,
# Nearest to five: mortally, actress, seven, minas, ramifications, influential, brassiere, sq,
# Nearest to prince: zoomed, roi, stave, parachutes, xie, unload, forgiving, paws,
# Nearest to rise: sky, az, deflate, ermey, salamanca, gorbachev, advantage, p,
# Nearest to test: smil, reliance, bytes, baptist, mmol, consequentialism, hillside, protocol,
# Nearest to operations: distinct, memorandum, restatement, art, idi, il, stouffer, incredible,
# Nearest to governor: united, privatization, estonian, polynesia, unicameral, geo, president, zhou,
# Nearest to mean: interesting, fick, oup, maillol, given, warship, installation, dysfunctional,
# Nearest to professional: competing, evaded, freeman, comically, ingesting, helmed, bitter, cheat,
# Nearest to instance: faithful, embedded, isuzu, hippocampus, unsatisfactory, nothing, orlogsflag, cutting,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6857 0.5763 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6420 0.5615 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6044 0.5690 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6223 0.5727 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6152 0.5665 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6555 0.5922 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5947 0.4447 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5616 0.5588 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4976 0.5790 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4807 0.6096 sec/batch
# Nearest to when: arm, hands, fabricated, uruguayan, gypsum, inglewood, vorkosigan, legalistic,
# Nearest to were: pwn, rumpus, nitrite, reconstruct, toothbrush, summary, chulainn, gaelic,
# Nearest to zero: five, nine, adp, migrant, million, nicolas, italian, six,
# Nearest to about: obese, apatosaurus, benefactors, addressing, whitey, fossilization, stating, worshipping,
# Nearest to from: messerschmitt, lollard, codifying, partition, invaded, gyre, hermetic, finalised,
# Nearest to nine: frank, chemist, greg, turkmenistan, gustaf, zero, brigade, economist,
# Nearest to his: sergey, alternativa, desi, famed, troubles, ito, tunic, interruption,
# Nearest to five: seven, actress, mortally, minas, zero, one, six, marquis,
# Nearest to prince: zoomed, roi, parachutes, forgiving, jos, stave, andrew, ezra,
# Nearest to rise: sky, az, deflate, micron, ermey, section, polanyi, muad,
# Nearest to test: smil, reliance, consequentialism, mmol, bytes, protocol, hillside, baptist,
# Nearest to operations: distinct, stouffer, memorandum, restatement, disadvantages, idi, mawson, groupoid,
# Nearest to governor: privatization, united, unicameral, estonian, president, polynesia, geo, zhou,
# Nearest to mean: interesting, given, fick, oup, installation, lines, maillol, dysfunctional,
# Nearest to professional: competing, freeman, ingesting, comically, cheat, evaded, bitter, helmed,
# Nearest to instance: embedded, hippocampus, faithful, isuzu, cutting, unsatisfactory, relative, composition,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4871 0.5264 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4830 0.4852 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4712 0.4629 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5486 0.4585 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4585 0.4567 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4768 0.4664 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4661 0.4787 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4064 0.4770 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4370 0.4590 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4137 0.4591 sec/batch
# Nearest to when: arm, hands, fabricated, vorkosigan, nontrivial, gypsum, legalistic, uruguayan,
# Nearest to were: pwn, toothbrush, rumpus, nitrite, chulainn, reconstruct, gaelic, summary,
# Nearest to zero: million, nine, migrant, five, adp, bbl, two, est,
# Nearest to about: apatosaurus, obese, whitey, reflecting, addressing, worshipping, vegans, nihilists,
# Nearest to from: lollard, partition, hermetic, messerschmitt, codifying, gyre, illegitimacy, invaded,
# Nearest to nine: frank, chemist, zero, aiken, greg, turkmenistan, gustaf, arity,
# Nearest to his: sergey, alternativa, desi, tunic, famed, interruption, troubles, ito,
# Nearest to five: minas, seven, zero, est, sq, mortally, missourians, ramifications,
# Nearest to prince: zoomed, roi, xie, parachutes, stave, ezra, forgiving, jos,
# Nearest to rise: sky, deflate, az, micron, ermey, vdots, riverdale, integration,
# Nearest to test: smil, reliance, consequentialism, bytes, protocol, mmol, pricking, niche,
# Nearest to operations: distinct, stouffer, memorandum, restatement, function, disadvantages, groupoid, mawson,
# Nearest to governor: unicameral, privatization, united, president, estonian, ministers, acquiring, polynesia,
# Nearest to mean: interesting, given, oup, fick, maillol, lines, montessori, dysfunctional,
# Nearest to professional: competing, freeman, cheat, ingesting, evaded, comically, helmed, fluffy,
# Nearest to instance: embedded, hippocampus, isuzu, faithful, rayon, unsatisfactory, cutting, emesa,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4298 0.4713 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4020 0.4653 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4452 0.4586 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3989 0.4761 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4101 0.4873 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4603 0.4652 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3805 0.4606 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3541 0.6439 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4214 0.5636 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3640 0.5870 sec/batch
# Nearest to when: arm, vorkosigan, hands, nontrivial, fabricated, gypsum, blasters, freewheelin,
# Nearest to were: pwn, toothbrush, nitrite, chulainn, summary, rumpus, blade, contacts,
# Nearest to zero: nine, five, migrant, million, two, adp, six, bbl,
# Nearest to about: apatosaurus, obese, whitey, kora, reflecting, addressing, fossilization, incompleteness,
# Nearest to from: lollard, hermetic, partition, sprung, gyre, codifying, case, messerschmitt,
# Nearest to nine: frank, chemist, zero, greg, gustaf, turkmenistan, two, aiken,
# Nearest to his: sergey, desi, alternativa, tunic, famed, him, surreptitiously, boii,
# Nearest to five: minas, seven, zero, est, ramifications, mortally, missourians, transatlantic,
# Nearest to prince: zoomed, roi, jos, xie, throne, forgiving, antiquated, stave,
# Nearest to rise: sky, deflate, az, ermey, micron, riverdale, promontory, muad,
# Nearest to test: smil, reliance, consequentialism, protocol, bytes, mmol, niche, pumps,
# Nearest to operations: distinct, stouffer, memorandum, asw, restatement, disadvantages, algorithm, mawson,
# Nearest to governor: unicameral, privatization, president, estonian, united, ministers, geo, polynesia,
# Nearest to mean: interesting, given, oup, fick, montessori, dysfunctional, transwomen, maillol,
# Nearest to professional: competing, freeman, ingesting, cheat, comically, bitter, nightlife, evaded,
# Nearest to instance: embedded, hippocampus, emesa, isuzu, unsatisfactory, analytically, rayon, cutting,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3672 0.5124 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3921 0.4958 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3749 0.5121 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3375 0.5424 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3866 0.6550 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3819 0.4844 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3903 0.4977 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3756 0.5358 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3500 0.5001 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3148 0.5193 sec/batch
# Nearest to when: arm, hands, vorkosigan, nontrivial, freewheelin, gypsum, uruguayan, fabricated,
# Nearest to were: toothbrush, pwn, rumpus, chulainn, constantinople, contacts, summary, monarchists,
# Nearest to zero: nine, five, two, migrant, million, six, deaths, est,
# Nearest to about: apatosaurus, obese, fossilization, reflecting, addressing, scientific, history, bihar,
# Nearest to from: partition, lollard, hermetic, seasonal, gyre, sprung, invaded, codifying,
# Nearest to nine: zero, frank, two, chemist, greg, three, aiken, gustaf,
# Nearest to his: desi, sergey, alternativa, boii, interruption, heretics, tunic, surreptitiously,
# Nearest to five: minas, zero, seven, est, three, ramifications, missourians, six,
# Nearest to prince: zoomed, roi, throne, xie, jos, turks, stave, prussia,
# Nearest to rise: sky, deflate, az, section, integration, riverdale, doubled, micron,
# Nearest to test: smil, protocol, consequentialism, bytes, reliance, mmol, niche, pumps,
# Nearest to operations: stouffer, distinct, memorandum, us, mawson, asw, algorithm, disadvantages,
# Nearest to governor: unicameral, privatization, president, ministers, estonian, united, acquiring, zhou,
# Nearest to mean: interesting, given, oup, fick, montessori, transwomen, dysfunctional, skeptic,
# Nearest to professional: competing, freeman, ingesting, cheat, fluffy, fan, comically, nightlife,
# Nearest to instance: embedded, hippocampus, faithful, unsatisfactory, isuzu, analytically, rayon, wir,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3645 0.6408 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3512 0.5496 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3824 0.5118 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.4132 0.5025 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3972 0.5223 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3025 0.5808 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3009 0.5620 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3181 0.5286 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2205 0.5870 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2998 0.6865 sec/batch
# Nearest to when: arm, vorkosigan, hands, tarleton, uruguayan, nontrivial, gypsum, freewheelin,
# Nearest to were: toothbrush, pwn, stay, contacts, blade, chulainn, rumpus, nitrite,
# Nearest to zero: migrant, two, five, nine, six, deaths, million, est,
# Nearest to about: apatosaurus, obese, bihar, reflecting, history, mtu, fossilization, scientific,
# Nearest to from: partition, invaded, hermetic, gyre, seasonal, codifying, sprung, lollard,
# Nearest to nine: frank, zero, chemist, two, greg, three, gustaf, biologist,
# Nearest to his: sergey, desi, alternativa, tunic, him, boii, heretics, chores,
# Nearest to five: zero, minas, seven, est, three, six, one, two,
# Nearest to prince: zoomed, roi, throne, prussia, jos, xie, browski, forgiving,
# Nearest to rise: sky, deflate, az, riverdale, micron, ermey, doubled, section,
# Nearest to test: smil, protocol, consequentialism, mmol, reliance, hillside, september, pumps,
# Nearest to operations: stouffer, distinct, memorandum, asw, identity, us, algorithm, mawson,
# Nearest to governor: unicameral, ministers, privatization, estonian, president, acquiring, tyrone, united,
# Nearest to mean: interesting, given, oup, fick, montessori, skeptic, quelques, transwomen,
# Nearest to professional: competing, freeman, skateboarder, cheat, ingesting, comically, helmed, limpbizkit,
# Nearest to instance: embedded, unsatisfactory, hippocampus, isuzu, faithful, rayon, grammar, analytically,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3125 0.6549 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3077 0.6826 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3425 0.3644 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2515 0.6637 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2443 0.6386 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2294 0.5948 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2002 0.7749 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2047 0.7487 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2309 0.6167 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1770 0.7003 sec/batch
# Nearest to when: arm, vorkosigan, hands, tarleton, uruguayan, freewheelin, delay, outfielder,
# Nearest to were: pwn, toothbrush, blade, stay, chulainn, contacts, hamilcar, reconstruct,
# Nearest to zero: two, migrant, five, nine, six, est, deaths, million,
# Nearest to about: apatosaurus, bihar, reflecting, coastline, kora, fossilization, obese, history,
# Nearest to from: invaded, partition, gyre, hermetic, sprung, lollard, seasonal, occupies,
# Nearest to nine: zero, frank, two, greg, chemist, three, gustaf, aiken,
# Nearest to his: sergey, desi, alternativa, tunic, boii, heretics, chores, proclus,
# Nearest to five: zero, minas, seven, three, est, six, one, two,
# Nearest to prince: zoomed, throne, cheering, roi, forgiving, browski, xie, parachutes,
# Nearest to rise: sky, deflate, az, promontory, riverdale, micron, doubled, gorbachev,
# Nearest to test: smil, protocol, mmol, consequentialism, reliance, september, niche, hillside,
# Nearest to operations: stouffer, us, memorandum, asw, algorithm, identity, distinct, function,
# Nearest to governor: unicameral, privatization, ministers, geo, bicameral, acquiring, president, bassas,
# Nearest to mean: interesting, oup, given, fick, quelques, montessori, immigration, corruptions,
# Nearest to professional: competing, freeman, cheat, skateboarder, ingesting, helmed, nightlife, afford,
# Nearest to instance: unsatisfactory, embedded, orlogsflag, hippocampus, faithful, emesa, analytically, isuzu,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2389 0.6689 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2308 0.6381 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2313 0.5564 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1317 0.6158 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1857 0.5400 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1815 0.6434 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1555 0.5376 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.2103 0.6605 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2109 0.5592 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1638 0.5653 sec/batch
# Nearest to when: arm, vorkosigan, hands, knee, vibrato, nontrivial, delay, tarleton,
# Nearest to were: pwn, stay, chulainn, blade, contacts, cab, unipolar, yakov,
# Nearest to zero: two, five, migrant, nine, six, million, est, one,
# Nearest to about: apatosaurus, kora, reflecting, history, obese, nihilists, bihar, fossilization,
# Nearest to from: hermetic, partition, gyre, lollard, cubits, seasonal, rhyolite, invaded,
# Nearest to nine: zero, frank, two, greg, three, aiken, chemist, gustaf,
# Nearest to his: sergey, desi, tunic, alternativa, chores, proclus, boii, heretics,
# Nearest to five: zero, seven, minas, three, est, six, one, two,
# Nearest to prince: zoomed, cheering, xie, roi, forgiving, browski, parachutes, throne,
# Nearest to rise: deflate, sky, promontory, micron, riverdale, basica, az, partitioning,
# Nearest to test: smil, protocol, mmol, consequentialism, reliance, september, pumps, hillside,
# Nearest to operations: stouffer, memorandum, us, asw, distinct, pulsation, algorithm, identity,
# Nearest to governor: unicameral, privatization, geo, bicameral, acquiring, ministers, president, bassas,
# Nearest to mean: interesting, oup, fick, given, immigration, quelques, montessori, corruptions,
# Nearest to professional: competing, freeman, skateboarder, ingesting, afford, cheat, affiliated, helmed,
# Nearest to instance: unsatisfactory, embedded, analytically, hippocampus, emesa, orlogsflag, isuzu, rayon,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1598 0.5679 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2343 0.6197 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1700 0.5756 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1496 0.5516 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2030 0.5090 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1951 0.4854 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2298 0.4935 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1721 0.4914 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1647 0.5465 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1951 0.5974 sec/batch
# Nearest to when: arm, vorkosigan, hands, tarleton, uruguayan, nontrivial, knee, delay,
# Nearest to were: pwn, contacts, blade, patriarchate, gini, stay, yakov, chulainn,
# Nearest to zero: two, five, migrant, nine, six, million, four, est,
# Nearest to about: apatosaurus, kora, fossilization, history, reflecting, scientific, norns, bihar,
# Nearest to from: hermetic, partition, invaded, lollard, gyre, trebuchet, cubits, foucault,
# Nearest to nine: zero, two, three, chemist, frank, greg, five, eight,
# Nearest to his: sergey, desi, proclus, alternativa, chores, laments, craig, observe,
# Nearest to five: zero, seven, three, one, est, minas, six, two,
# Nearest to prince: zoomed, cheering, throne, forgiving, roi, xie, browski, hohenstaufen,
# Nearest to rise: sky, deflate, promontory, lifo, ermey, gyro, riverdale, basica,
# Nearest to test: smil, protocol, mmol, consequentialism, reliance, september, hillside, pumps,
# Nearest to operations: stouffer, memorandum, asw, us, pulsation, identity, algorithm, groupoid,
# Nearest to governor: unicameral, privatization, bicameral, ministers, president, geo, acquiring, tyrone,
# Nearest to mean: interesting, oup, given, fick, immigration, corruptions, pistols, quelques,
# Nearest to professional: competing, freeman, skateboarder, cheat, ingesting, affiliated, helmed, afford,
# Nearest to instance: unsatisfactory, analytically, orlogsflag, embedded, hippocampus, emesa, faithful, isuzu,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2076 0.5628 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1923 0.5362 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1700 0.5851 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1799 0.6380 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1522 0.6485 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1079 0.5576 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1878 0.5833 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1812 0.6665 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1978 0.5647 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1951 0.5655 sec/batch
# Nearest to when: arm, tarleton, uruguayan, vorkosigan, hands, westernmost, schisms, outfielder,
# Nearest to were: stay, yakov, patriarchate, pwn, contacts, monarchists, gini, chulainn,
# Nearest to zero: two, five, nine, migrant, six, deaths, one, four,
# Nearest to about: apatosaurus, history, kora, bihar, leiber, reflecting, mtu, genevieve,
# Nearest to from: invaded, hermetic, partition, foucault, thebes, gyre, lollard, trebuchet,
# Nearest to nine: zero, two, three, frank, greg, chemist, five, eight,
# Nearest to his: sergey, desi, alternativa, him, laments, craig, proclus, lawson,
# Nearest to five: zero, seven, three, one, two, six, four, minas,
# Nearest to prince: zoomed, cheering, throne, forgiving, roi, browski, makhno, hohenstaufen,
# Nearest to rise: sky, promontory, deflate, dravidians, ermey, extrajudicial, lifo, megaliths,
# Nearest to test: smil, protocol, mmol, consequentialism, reliance, september, cricket, frenchman,
# Nearest to operations: memorandum, stouffer, us, asw, declared, pulsation, identity, groupoid,
# Nearest to governor: unicameral, privatization, geo, bicameral, tyrone, acquiring, ministers, misgivings,
# Nearest to mean: interesting, oup, fick, given, pistols, scholasticism, immigration, corruptions,
# Nearest to professional: competing, freeman, skateboarder, helmed, affiliated, cheat, ingesting, limpbizkit,
# Nearest to instance: orlogsflag, unsatisfactory, analytically, embedded, faithful, hippocampus, emesa, isuzu,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2336 0.5819 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1350 0.6194 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1154 0.6249 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1356 0.8032 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0412 0.6629 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1528 0.5661 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1486 0.6232 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1237 0.5564 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1879 0.1011 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1306 0.5089 sec/batch
# Nearest to when: arm, vorkosigan, hands, delay, outfielder, tarleton, knee, uruguayan,
# Nearest to were: blade, cab, saturdays, stay, gini, yakov, contacts, pwn,
# Nearest to zero: two, five, migrant, nine, six, four, one, female,
# Nearest to about: apatosaurus, history, reflecting, obese, fossilization, bihar, disorders, kora,
# Nearest to from: hermetic, partition, invaded, the, gyre, njimi, cubits, sprung,
# Nearest to nine: zero, two, three, frank, greg, five, chemist, one,
# Nearest to his: sergey, desi, alternativa, observe, laments, lawson, chores, proclus,
# Nearest to five: zero, seven, three, two, one, six, four, est,
# Nearest to prince: zoomed, forgiving, cheering, throne, roi, almohades, stroke, browski,
# Nearest to rise: promontory, sky, gyro, dravidians, riverdale, extrajudicial, deflate, lifo,
# Nearest to test: smil, protocol, mmol, consequentialism, cricket, reliance, september, frenchman,
# Nearest to operations: stouffer, memorandum, asw, identity, us, pulsation, function, groupoid,
# Nearest to governor: unicameral, geo, privatization, tyrone, ministers, bicameral, bassas, misgivings,
# Nearest to mean: interesting, oup, given, fick, pistols, quelques, montessori, scholasticism,
# Nearest to professional: competing, skateboarder, helmed, freeman, affiliated, cheat, ingesting, afford,
# Nearest to instance: analytically, orlogsflag, unsatisfactory, hippocampus, embedded, faithful, isuzu, emesa,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0901 0.4811 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.1183 0.5451 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0948 0.5489 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0684 0.5029 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0764 0.6004 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0415 0.5043 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1033 0.5054 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0776 0.4571 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1263 0.4895 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0292 0.5484 sec/batch
# Nearest to when: arm, hands, knee, tarleton, vorkosigan, delay, uruguayan, outfielder,
# Nearest to were: cab, gini, stay, contacts, blade, saturdays, yakov, encircling,
# Nearest to zero: two, five, migrant, nine, six, four, one, years,
# Nearest to about: apatosaurus, history, reflecting, coastline, kora, peaks, shroud, fossilization,
# Nearest to from: invaded, partition, the, njimi, hermetic, rhyolite, gyre, is,
# Nearest to nine: zero, two, three, greg, frank, five, six, four,
# Nearest to his: sergey, desi, alternativa, observe, him, chores, anselm, boii,
# Nearest to five: zero, seven, three, two, six, one, four, minas,
# Nearest to prince: zoomed, cheering, forgiving, throne, stroke, browski, roi, almohades,
# Nearest to rise: promontory, sky, deflate, ermey, gyro, doubled, dravidians, az,
# Nearest to test: smil, cricket, protocol, mmol, september, consequentialism, reliance, sydney,
# Nearest to operations: stouffer, memorandum, asw, identity, us, function, pulsation, firepower,
# Nearest to governor: unicameral, bicameral, ministers, privatization, geo, tyrone, acquiring, misgivings,
# Nearest to mean: oup, interesting, given, fick, pistols, corruptions, quelques, scholasticism,
# Nearest to professional: competing, affiliated, skateboarder, helmed, afford, cheat, freeman, ensure,
# Nearest to instance: orlogsflag, unsatisfactory, analytically, hippocampus, emesa, faithful, temp, dictated,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0222 0.5023 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0396 0.4948 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9991 0.4939 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0318 0.4699 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0879 0.5796 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0431 0.6837 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0786 0.5991 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1182 0.4755 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0780 0.4632 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0560 0.5115 sec/batch
# Nearest to when: arm, vorkosigan, delay, hands, switch, vibrato, knee, nontrivial,
# Nearest to were: gini, blade, cab, pitts, manche, contacts, pwn, outbursts,
# Nearest to zero: two, five, migrant, nine, six, one, four, million,
# Nearest to about: apatosaurus, kora, reflecting, obese, norns, history, fossilization, multilayered,
# Nearest to from: hermetic, the, partition, cubits, gyre, njimi, rhyolite, invaded,
# Nearest to nine: zero, two, three, five, greg, frank, eight, six,
# Nearest to his: sergey, chores, observe, desi, alternativa, craig, proclus, lawson,
# Nearest to five: zero, seven, three, two, one, six, four, minas,
# Nearest to prince: cheering, zoomed, forgiving, browski, throne, stroke, roi, hohenstaufen,
# Nearest to rise: promontory, sky, deflate, dravidians, ermey, disassembly, lifo, feedback,
# Nearest to test: smil, protocol, mmol, cricket, consequentialism, september, reliance, tests,
# Nearest to operations: stouffer, memorandum, identity, asw, function, pulsation, us, declared,
# Nearest to governor: unicameral, privatization, geo, bicameral, ministers, tyrone, misgivings, acquiring,
# Nearest to mean: oup, interesting, pistols, given, fick, scholasticism, immigration, corruptions,
# Nearest to professional: competing, affiliated, skateboarder, helmed, ensure, afford, ingesting, symbian,
# Nearest to instance: analytically, unsatisfactory, orlogsflag, hippocampus, emesa, temp, preterist, karakoram,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0607 0.4739 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0962 0.5767 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.1192 0.4823 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0522 0.4867 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0850 0.7250 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0812 0.5846 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0568 0.5357 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0710 0.5573 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1016 0.5906 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0845 0.4887 sec/batch
# Nearest to when: arm, tarleton, vorkosigan, delay, hands, westernmost, switch, nus,
# Nearest to were: patriarchate, contacts, yakov, gini, in, encircling, manche, hamilcar,
# Nearest to zero: two, five, nine, migrant, six, one, four, million,
# Nearest to about: apatosaurus, history, sangha, norns, fossilization, disorders, obese, reflecting,
# Nearest to from: the, invaded, partition, trebuchet, njimi, gyre, hermetic, is,
# Nearest to nine: zero, two, three, greg, five, eight, six, frank,
# Nearest to his: sergey, him, desi, alternativa, boii, observe, croesus, chores,
# Nearest to five: zero, three, seven, two, one, six, four, est,
# Nearest to prince: throne, cheering, zoomed, forgiving, uniformity, hohenstaufen, roi, stroke,
# Nearest to rise: promontory, dravidians, sky, gyro, lifo, gorbachev, integration, deflate,
# Nearest to test: protocol, cricket, smil, mmol, september, consequentialism, tests, reliance,
# Nearest to operations: stouffer, memorandum, asw, identity, us, function, declared, pago,
# Nearest to governor: unicameral, geo, tyrone, bicameral, ministers, misgivings, privatization, backfired,
# Nearest to mean: oup, interesting, pistols, given, fick, scholasticism, antinomies, immigration,
# Nearest to professional: competing, affiliated, skateboarder, helmed, ensure, nightlife, ingesting, afford,
# Nearest to instance: orlogsflag, analytically, unsatisfactory, karakoram, temp, hippocampus, dictated, faithful,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0621 0.4617 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0042 0.4544 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0333 0.4672 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0805 0.4504 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.1065 0.4515 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1534 0.4554 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1540 0.4562 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0468 0.4630 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0587 0.4846 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0519 0.4456 sec/batch
# Nearest to when: arm, tarleton, vorkosigan, switch, aelius, uruguayan, westernmost, delay,
# Nearest to were: gini, contacts, outbursts, blade, yakov, pwn, moruroa, utterly,
# Nearest to zero: two, five, nine, migrant, four, six, one, million,
# Nearest to about: apatosaurus, history, norns, reflecting, leiber, genevieve, sangha, obese,
# Nearest to from: invaded, the, partition, trebuchet, gyre, njimi, hermetic, rhyolite,
# Nearest to nine: zero, two, three, five, greg, six, four, frank,
# Nearest to his: him, sergey, desi, chores, alternativa, observe, laments, lawson,
# Nearest to five: zero, three, two, seven, six, four, one, est,
# Nearest to prince: throne, cheering, zoomed, forgiving, stroke, roi, hohenstaufen, browski,
# Nearest to rise: promontory, dravidians, sky, gyro, ipkf, partitioning, gorbachev, kaveri,
# Nearest to test: protocol, cricket, smil, mmol, tests, consequentialism, september, sydney,
# Nearest to operations: stouffer, memorandum, asw, identity, handley, pago, declared, us,
# Nearest to governor: tyrone, unicameral, geo, misgivings, privatization, bicameral, ministers, backfired,
# Nearest to mean: oup, interesting, pistols, given, fick, antinomies, montessori, corruptions,
# Nearest to professional: competing, affiliated, helmed, skateboarder, ingesting, paxton, nightlife, symbian,
# Nearest to instance: orlogsflag, unsatisfactory, analytically, isuzu, karakoram, temp, faithful, pounder,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9622 0.4547 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0476 0.4584 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0373 0.4572 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0418 0.4468 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0927 0.4490 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0735 0.4359 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0287 0.4526 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9942 0.4400 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9966 0.4447 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9899 0.4888 sec/batch
# Nearest to when: arm, tarleton, aelius, delay, hands, permanently, outfielder, hobart,
# Nearest to were: blade, gini, stay, lugdunum, utterly, contacts, hamilcar, yakov,
# Nearest to zero: two, five, nine, four, one, six, migrant, three,
# Nearest to about: apatosaurus, norns, history, september, bihar, coastline, peaks, kora,
# Nearest to from: the, invaded, gyre, rhyolite, partition, njimi, is, cubits,
# Nearest to nine: zero, two, three, one, five, six, greg, eight,
# Nearest to his: him, observe, croesus, proclus, alternativa, chores, sergey, caesaris,
# Nearest to five: zero, seven, two, three, six, one, four, nine,
# Nearest to prince: cheering, throne, zoomed, forgiving, browski, stroke, uniformity, roi,
# Nearest to rise: promontory, dravidians, sky, gyro, nizam, megaliths, showman, gorbachev,
# Nearest to test: cricket, smil, protocol, mmol, september, tests, sydney, consequentialism,
# Nearest to operations: stouffer, memorandum, asw, identity, us, armory, carrier, handley,
# Nearest to governor: unicameral, tyrone, geo, bicameral, misgivings, ministers, cornelis, privatization,
# Nearest to mean: pistols, oup, interesting, given, fick, antinomies, immigration, corruptions,
# Nearest to professional: competing, affiliated, helmed, skateboarder, paxton, symbian, afford, mediators,
# Nearest to instance: orlogsflag, unsatisfactory, analytically, temp, emesa, isuzu, pounder, karakoram,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9946 0.4541 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9311 0.4459 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0114 0.4473 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9873 0.4457 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0256 0.4466 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0043 0.4510 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9081 0.5765 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9547 0.4609 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9389 0.4844 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9599 0.4474 sec/batch
# Nearest to when: arm, outfielder, tarleton, hands, delay, switch, knee, hobart,
# Nearest to were: gini, moruroa, manche, blade, dillon, hamilcar, yakov, encircling,
# Nearest to zero: two, five, nine, four, six, migrant, one, three,
# Nearest to about: apatosaurus, norns, history, coastline, seedlessness, reflecting, bihar, shroud,
# Nearest to from: the, is, out, rhyolite, invaded, njimi, gyre, partition,
# Nearest to nine: zero, two, three, five, six, four, one, eight,
# Nearest to his: sergey, him, observe, tunic, spent, chores, proclus, desi,
# Nearest to five: zero, two, three, seven, six, four, one, nine,
# Nearest to prince: cheering, zoomed, forgiving, throne, stroke, uniformity, browski, hohenstaufen,
# Nearest to rise: promontory, dravidians, showman, feedback, gyro, sky, integration, partitioning,
# Nearest to test: cricket, smil, protocol, mmol, tests, september, sydney, consequentialism,
# Nearest to operations: stouffer, memorandum, asw, identity, citigroup, idi, combatants, pago,
# Nearest to governor: unicameral, bicameral, tyrone, geo, misgivings, privatization, ministers, surveyor,
# Nearest to mean: oup, pistols, interesting, fick, given, immigration, antinomies, corruptions,
# Nearest to professional: competing, affiliated, skateboarder, helmed, afford, symbian, ensure, camouflage,
# Nearest to instance: orlogsflag, unsatisfactory, analytically, temp, emesa, imposed, embedded, karakoram,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9947 0.4448 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0136 0.4382 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9770 0.4413 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0334 0.4376 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0600 0.4434 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9356 0.4390 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9988 0.4375 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0005 0.4421 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0151 0.4534 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0178 0.4382 sec/batch
# Nearest to when: arm, tarleton, delay, vorkosigan, switch, outfielder, hands, insistent,
# Nearest to were: gini, moruroa, manche, blade, contacts, pwn, cab, struts,
# Nearest to zero: two, five, nine, four, one, six, migrant, three,
# Nearest to about: apatosaurus, biography, norns, leiber, genevieve, september, kora, history,
# Nearest to from: the, is, at, invaded, regio, elbl, there, partition,
# Nearest to nine: zero, two, three, eight, five, one, six, four,
# Nearest to his: sergey, observe, him, spent, desi, proclus, chores, laments,
# Nearest to five: zero, seven, two, three, six, one, four, nine,
# Nearest to prince: throne, cheering, uniformity, zoomed, forgiving, hohenstaufen, browski, reign,
# Nearest to rise: promontory, feedback, showman, ermey, dravidians, disassembly, gorbachev, seminar,
# Nearest to test: cricket, protocol, smil, tests, september, mmol, sydney, mauser,
# Nearest to operations: stouffer, memorandum, asw, identity, citigroup, idi, incredible, combatants,
# Nearest to governor: unicameral, bicameral, geo, tyrone, surveyor, cornelis, privatization, ministers,
# Nearest to mean: pistols, oup, interesting, given, fick, antinomies, immigration, scholasticism,
# Nearest to professional: competing, affiliated, helmed, skateboarder, symbian, afford, ensure, paxton,
# Nearest to instance: orlogsflag, unsatisfactory, analytically, temp, emesa, isuzu, dictated, corrode,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0008 0.4765 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9797 0.4463 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9887 0.4463 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0248 0.4522 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0004 0.4357 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0188 0.4331 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9934 0.4332 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9740 0.4366 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9452 0.4430 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0517 0.4402 sec/batch
# Nearest to when: arm, tarleton, westernmost, permanently, delay, switch, insistent, increasing,
# Nearest to were: gini, in, manche, early, precedence, yakov, contacts, moruroa,
# Nearest to zero: two, five, nine, six, four, one, three, migrant,
# Nearest to about: history, apatosaurus, september, biography, bihar, genevieve, coastline, unikom,
# Nearest to from: the, invaded, is, partition, at, gyre, elbl, on,
# Nearest to nine: zero, two, three, five, one, eight, six, four,
# Nearest to his: him, spent, sergey, observe, caesaris, desi, he, valet,
# Nearest to five: zero, two, seven, three, one, six, four, nine,
# Nearest to prince: throne, cheering, uniformity, zoomed, forgiving, stroke, princess, hohenstaufen,
# Nearest to rise: dravidians, promontory, nizam, kaveri, megaliths, feedback, showman, partitioning,
# Nearest to test: cricket, protocol, tests, mmol, smil, september, consequentialism, sydney,
# Nearest to operations: stouffer, memorandum, asw, identity, citigroup, handley, idi, declared,
# Nearest to governor: bicameral, tyrone, unicameral, geo, misgivings, surveyor, ministers, cornelis,
# Nearest to mean: pistols, oup, interesting, antinomies, given, fick, deo, corruptions,
# Nearest to professional: competing, affiliated, helmed, skateboarder, symbian, ingesting, afford, nightlife,
# Nearest to instance: orlogsflag, unsatisfactory, analytically, temp, phi, isuzu, faithful, consists,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9951 0.4529 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.1156 0.4382 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0510 0.4314 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0406 0.4316 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9544 0.4290 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9597 0.4336 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9961 0.4331 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9573 0.4306 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 4.0168 0.4321 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9877 0.4335 sec/batch
# Nearest to when: arm, tarleton, permanently, delay, switch, hobart, insistent, increasing,
# ...
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8105 0.5065 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7808 0.5067 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7951 0.5090 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8675 0.5223 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8808 0.5019 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8251 0.5031 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8565 0.4996 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9235 0.4988 sec/batch
# Nearest to when: a, to, leave, insistent, falling, tremens, arm, this,
# Nearest to were: early, precedence, in, offs, dillon, reasons, influential, they,
# Nearest to zero: two, five, four, one, three, six, nine, eight,
# Nearest to about: of, said, from, biography, this, unicorns, norns, births,
# Nearest to from: the, and, of, in, is, a, as, to,
# Nearest to nine: three, two, one, zero, five, eight, six, four,
# Nearest to his: him, he, spent, died, tunic, earned, albano, brother,
# Nearest to five: two, zero, seven, four, three, one, six, nine,
# Nearest to prince: cheering, uniformity, andrew, princess, och, ruled, termite, throne,
# Nearest to rise: nizam, showman, cremated, dravidians, zarqawi, antofagasta, doubled, partitioning,
# Nearest to test: cricket, tests, bradman, batsmen, bowlers, mmol, methodology, sydney,
# Nearest to operations: stouffer, citigroup, combatants, identity, asw, clustering, armand, art,
# Nearest to governor: trenton, simmonds, cornelis, surveyor, unicameral, geo, quotient, fraser,
# Nearest to mean: oup, ocs, pistols, voyaging, variance, skeptic, trilateral, sabor,
# Nearest to professional: affiliated, competing, skateboarder, specialty, allowances, camouflage, peddle, competitions,
# Nearest to instance: orlogsflag, phi, temp, unsatisfactory, resemblance, fungi, emesa, determines,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8373 0.5176 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8653 0.5123 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8589 0.5144 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8825 0.5235 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.9008 0.5227 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8652 0.5158 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8752 0.5242 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8531 0.5236 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.9087 0.5395 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8722 0.4737 sec/batch
# Nearest to when: falling, leave, this, a, tarleton, to, insistent, westernmost,
# Nearest to were: early, in, by, the, precedence, after, offs, time,
# Nearest to zero: two, five, four, three, one, six, nine, eight,
# Nearest to about: of, is, from, said, to, this, have, norns,
# Nearest to from: the, and, in, of, is, a, by, as,
# Nearest to nine: three, two, one, zero, eight, five, six, four,
# Nearest to his: him, he, died, spent, albano, brother, observe, uncle,
# Nearest to five: two, zero, seven, four, three, six, one, nine,
# Nearest to prince: cheering, throne, ruled, princess, uniformity, reign, perils, proust,
# Nearest to rise: nizam, zarqawi, showman, dravidians, antofagasta, cremated, doubled, ciliates,
# Nearest to test: cricket, tests, bradman, batsmen, bowlers, mmol, sydney, methodology,
# Nearest to operations: stouffer, citigroup, identity, combatants, asw, memorandum, subtraction, art,
# Nearest to governor: trenton, unicameral, simmonds, cornelis, yap, elected, surveyor, bicameral,
# Nearest to mean: ocs, oup, variance, voyaging, antinomies, pistols, skeptic, trilateral,
# Nearest to professional: affiliated, competing, skateboarder, specialty, allowances, camouflage, peddle, helmed,
# Nearest to instance: phi, orlogsflag, temp, unsatisfactory, fungi, emesa, unitary, determines,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8820 0.4617 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8343 0.4599 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8337 0.4695 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8407 0.4508 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9263 0.4447 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8830 0.4418 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 4.0097 0.4497 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8847 0.4561 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9264 0.4459 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8179 0.4462 sec/batch
# Nearest to when: to, a, this, in, falling, leave, insistent, tremens,
# Nearest to were: early, in, the, after, precedence, reasons, they, by,
# Nearest to zero: two, five, four, six, three, nine, one, eight,
# Nearest to about: of, from, said, biography, this, births, to, is,
# Nearest to from: the, and, of, in, at, by, on, a,
# Nearest to nine: three, two, zero, one, five, eight, six, four,
# Nearest to his: him, he, died, spent, brother, was, earned, shuja,
# Nearest to five: two, zero, four, seven, three, six, one, nine,
# Nearest to prince: cheering, princess, throne, uniformity, ruled, stroke, andrew, termite,
# Nearest to rise: nizam, dravidians, antofagasta, zarqawi, doubled, partitioning, cremated, kaveri,
# Nearest to test: cricket, tests, bradman, batsmen, bowlers, mmol, protocol, sydney,
# Nearest to operations: stouffer, citigroup, identity, combatants, asw, memorandum, armand, subtraction,
# Nearest to governor: trenton, simmonds, cornelis, yap, fraser, surveyor, unicameral, quotient,
# Nearest to mean: oup, ocs, trilateral, antinomies, voyaging, pistols, tta, variance,
# Nearest to professional: affiliated, competing, skateboarder, allowances, camouflage, helmed, aviation, specialty,
# Nearest to instance: orlogsflag, unsatisfactory, temp, phi, fungi, emesa, determines, unitary,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8110 0.4482 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8637 0.4458 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7918 0.4433 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8756 0.4431 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8387 0.4461 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8599 0.4455 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8949 0.2634 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8140 0.4568 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8518 0.4434 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8605 0.4432 sec/batch
# Nearest to when: a, to, this, leave, in, the, tremens, of,
# Nearest to were: early, in, the, after, precedence, they, by, reasons,
# Nearest to zero: two, five, four, three, six, one, nine, eight,
# Nearest to about: of, is, from, this, said, to, point, and,
# Nearest to from: the, and, of, in, is, a, as, on,
# Nearest to nine: three, one, two, eight, zero, five, six, four,
# Nearest to his: he, him, died, spent, brother, was, father, bragi,
# Nearest to five: two, four, zero, seven, three, six, one, nine,
# Nearest to prince: princess, cheering, ruled, throne, uniformity, stroke, proust, termite,
# Nearest to rise: nizam, antofagasta, dravidians, doubled, cremated, ciliates, zarqawi, kaveri,
# Nearest to test: cricket, tests, bradman, batsmen, bowlers, mmol, sydney, negotiated,
# Nearest to operations: stouffer, identity, citigroup, combatants, asw, art, subtraction, clustering,
# Nearest to governor: simmonds, cornelis, trenton, unicameral, yap, fraser, prosthetic, elected,
# Nearest to mean: ocs, oup, variance, trilateral, pistols, voyaging, angie, sabor,
# Nearest to professional: affiliated, competing, skateboarder, allowances, helmed, camouflage, specialty, aviation,
# Nearest to instance: temp, unsatisfactory, orlogsflag, phi, fungi, emesa, determines, resemblance,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8020 0.4478 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8007 0.4460 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8373 0.4487 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8249 0.4461 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8398 0.4541 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8339 0.4433 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8875 0.4553 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7758 0.4609 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8059 0.4511 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8018 0.4460 sec/batch
# Nearest to when: a, to, in, for, leave, the, falling, this,
# Nearest to were: early, they, precedence, in, time, reasons, dillon, the,
# Nearest to zero: two, five, four, three, one, six, nine, eight,
# Nearest to about: of, said, from, is, this, births, to, have,
# Nearest to from: the, and, of, in, is, a, as, by,
# Nearest to nine: three, two, one, zero, five, eight, six, four,
# Nearest to his: him, he, spent, died, shuja, earned, brother, bragi,
# Nearest to five: two, zero, four, three, seven, six, one, nine,
# Nearest to prince: cheering, termite, princess, uniformity, proust, och, cuboctahedra, stroke,
# Nearest to rise: nizam, antofagasta, showman, cremated, dravidians, zarqawi, partitioning, doubled,
# Nearest to test: cricket, tests, bradman, batsmen, bowlers, mmol, sydney, prove,
# Nearest to operations: stouffer, citigroup, combatants, identity, asw, art, subtraction, armand,
# Nearest to governor: cornelis, simmonds, fraser, prosthetic, unicameral, yap, trenton, elected,
# Nearest to mean: oup, ocs, trilateral, variance, december, pistols, angie, voyaging,
# Nearest to professional: affiliated, competing, skateboarder, allowances, camouflage, specialty, helmed, training,
# Nearest to instance: phi, temp, unsatisfactory, fungi, orlogsflag, determines, emesa, for,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7393 0.4536 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8555 0.4471 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8484 0.5092 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8497 0.4479 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7959 0.4463 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9230 0.4446 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8570 0.4430 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8125 0.4538 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8377 0.4434 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8525 0.4423 sec/batch
# Nearest to when: a, leave, this, to, falling, tremens, insistent, in,
# Nearest to were: early, in, they, precedence, time, dillon, by, the,
# Nearest to zero: two, five, four, three, one, six, nine, eight,
# Nearest to about: of, said, from, this, to, is, births, have,
# Nearest to from: the, and, in, is, of, a, as, by,
# Nearest to nine: three, one, two, zero, eight, five, six, four,
# Nearest to his: him, he, died, spent, shuja, albano, posthumously, brother,
# Nearest to five: two, zero, four, seven, three, six, one, nine,
# Nearest to prince: princess, throne, cheering, uniformity, ruled, ascended, toku, reign,
# Nearest to rise: nizam, showman, cremated, zarqawi, doubled, dravidians, antofagasta, p,
# Nearest to test: cricket, tests, bradman, batsmen, bowlers, mmol, methodology, protocol,
# Nearest to operations: stouffer, citigroup, combatants, identity, asw, armand, art, subtraction,
# Nearest to governor: cornelis, simmonds, unicameral, fraser, trenton, yap, quotient, elected,
# Nearest to mean: ocs, trilateral, variance, oup, voyaging, angie, worthy, pistols,
# Nearest to professional: affiliated, competing, skateboarder, allowances, specialty, camouflage, peddle, training,
# Nearest to instance: fungi, phi, temp, orlogsflag, unsatisfactory, or, emesa, determines,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8839 0.4540 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8327 0.4462 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8364 0.4475 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8349 0.4442 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8809 0.4503 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8499 0.4548 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8318 0.4485 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8556 0.4491 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8070 0.4490 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8081 0.4434 sec/batch
# Nearest to when: a, to, this, in, of, the, leave, for,
# Nearest to were: early, in, the, by, they, time, precedence, these,
# Nearest to zero: two, four, five, three, six, one, nine, eight,
# Nearest to about: of, from, to, is, this, have, and, said,
# Nearest to from: the, and, of, in, is, a, by, to,
# Nearest to nine: three, two, one, eight, zero, five, six, four,
# Nearest to his: him, he, died, spent, brother, shuja, caesaris, earned,
# Nearest to five: two, four, zero, seven, three, six, one, nine,
# Nearest to prince: cheering, princess, throne, uniformity, ruled, ascended, toku, och,
# Nearest to rise: nizam, zarqawi, dravidians, partitioning, showman, ciliates, doubled, kaveri,
# Nearest to test: cricket, tests, bradman, batsmen, bowlers, mmol, methodology, protocol,
# Nearest to operations: stouffer, citigroup, identity, combatants, asw, art, subtraction, armand,
# Nearest to governor: unicameral, cornelis, trenton, yap, fraser, simmonds, elected, graphite,
# Nearest to mean: ocs, oup, worthy, trilateral, voyaging, antinomies, variance, pistols,
# Nearest to professional: affiliated, competing, skateboarder, allowances, camouflage, peddle, aviation, helmed,
# Nearest to instance: orlogsflag, fungi, phi, temp, unsatisfactory, for, or, emesa,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8609 0.4532 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8614 0.4499 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9446 0.4541 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9271 0.4549 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8871 0.4464 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8499 0.4477 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7790 0.4421 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8394 0.4481 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7363 0.4527 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8738 0.4470 sec/batch
# Nearest to when: to, a, in, leave, this, the, of, neutral,
# Nearest to were: early, in, the, after, time, by, influential, they,
# Nearest to zero: two, four, five, three, six, one, nine, eight,
# Nearest to about: of, to, from, this, is, said, births, article,
# Nearest to from: the, and, of, in, a, is, to, by,
# Nearest to nine: one, three, two, zero, eight, six, five, four,
# Nearest to his: him, he, died, spent, shuja, brother, bragi, caesaris,
# Nearest to five: two, zero, four, seven, three, six, one, nine,
# Nearest to prince: cheering, throne, princess, uniformity, proust, och, toku, termite,
# Nearest to rise: nizam, doubled, zarqawi, dravidians, outside, showman, ciliates, partitioning,
# Nearest to test: cricket, tests, bradman, batsmen, bowlers, mmol, protocol, prove,
# Nearest to operations: stouffer, identity, citigroup, combatants, asw, subtraction, celebes, armand,
# Nearest to governor: trenton, cornelis, unicameral, graphite, yap, fraser, simmonds, elected,
# Nearest to mean: ocs, variance, trilateral, worthy, antinomies, voyaging, oup, deportations,
# Nearest to professional: affiliated, competing, skateboarder, helmed, allowances, aviation, peddle, camouflage,
# Nearest to instance: temp, fungi, unsatisfactory, phi, orlogsflag, emesa, or, determines,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8364 0.4545 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8531 0.4491 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
