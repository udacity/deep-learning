# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter

# compute the frequency of each words in the dataset
word_counts = Counter(int_words)
total_words = len(int_words)

# display the most common repeated words
print(word_counts.most_common(10))
# Out:
# [(0, 1061396), (1, 593677), (2, 416629), (3, 411764), (4, 372201), (5, 325873), (6, 316376), (7, 264975), (8, 250430), (9, 192644)]

# %%
# define the threashold for removing a word that show up a lot
t = 1e-5

word_probs = dict()

# compute the frequency of each word by dividing the count for the total number of words in the dataset
word_freq = {word: count/total_words for word, count in word_counts.items()}

# %%
prob_to_drop = {word: 1.0 - np.sqrt(t / word_freq[word]) for word in word_counts}

# %%
import random

## Your code here
## remove all words with threashold greater than [t]
train_words = [word for word in int_words if prob_to_drop[word] < random.random()]

# %%
# Display new metadata about words, after subsampling
print("Total words: {}".format(len(train_words)))
print("Unique words: {}".format(len(set(train_words))))
# Out:
# Total words: 4627553
# Unique words: 63641

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''

    # Your code here
    # sample a random number from 1 to window_size
    R = np.random.randint(1, window_size+1)
    
    # compute the window's limits so that it can deal with out of bounds indeces
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    
    # return a list of unique words
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    # batch full of integers representing the source of context words
    inputs = tf.placeholder(tf.int32, [None], name="inputs_placeholder") 
    
    # batch full of integers representing the target words
    labels = tf.placeholder(tf.int32, [None, None], name="labels_placeholder")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200# Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab,n_embedding), -1.0, 1.0), name="embedding_matrix") # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample

n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights=softmax_w, biases=softmax_b, 
                                      labels=labels, inputs=embed, 
                                      num_sampled=n_sampled, num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6538 0.0675 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6182 0.0668 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5144 0.0666 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6037 0.0669 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5400 0.0668 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5535 0.0670 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5612 0.0668 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5494 0.0661 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4661 0.0655 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4172 0.0650 sec/batch
# Nearest to not: nemours, days, cplp, doped, redirected, stakeholders, fergus, fyodorovna,
# Nearest to there: contemporaries, humiliating, kinsmen, deals, hemispheres, goldfinches, casablanca, searing,
# Nearest to many: army, dissolves, plumage, blueberry, apical, buchner, consolidate, furious,
# Nearest to three: martial, event, honoria, alcock, balcony, eschatology, aqueducts, bay,
# Nearest to b: verit, supervillain, ltcm, nlt, clothed, kegan, arene, possessed,
# Nearest to but: beery, referees, engaged, carbonyl, xps, rostov, halides, mri,
# Nearest to have: flooded, although, bite, married, impermeable, kirghiz, thornton, relaxed,
# Nearest to american: army, tesla, bursting, coastlands, visits, nantes, residences, parenthood,
# Nearest to hold: team, cisleithania, recalcitrant, displacements, rennie, rectifier, possibly, samoans,
# Nearest to channel: alamanni, subatomic, elgamal, mercalli, toads, embarrassing, tracked, kitchen,
# Nearest to universe: inroads, roach, comprehensive, status, confers, along, waterston, novello,
# Nearest to report: quirin, tariffs, axel, indeed, projector, rips, wander, asians,
# Nearest to orthodox: nder, anastasia, inanimate, midianites, hospitalised, dxm, competing, appreciative,
# Nearest to proposed: ceasefire, bret, willers, thanking, haig, repaired, loadable, silty,
# Nearest to issue: tenets, japheth, bypassing, impacted, transition, sie, adherents, taxation,
# Nearest to pope: thinly, anise, seduced, accord, smashed, supergravity, chunnel, taika,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4816 0.0660 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3821 0.0650 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3475 0.0649 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2587 0.0650 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1708 0.0651 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1694 0.0651 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1134 0.0649 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0751 0.0652 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0219 0.0652 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0042 0.0653 sec/batch
# Nearest to not: days, enhance, cases, nemours, doped, nes, sexually, redirected,
# Nearest to there: deals, humiliating, contemporaries, accepted, hemispheres, bears, goldfinches, euclidean,
# Nearest to many: dissolves, humanity, army, cash, consolidate, do, ratio, plumage,
# Nearest to three: event, bay, martial, diego, football, british, honoria, min,
# Nearest to b: possessed, supervillain, structure, drummer, ohm, vegeta, oup, kegan,
# Nearest to but: beery, referees, engaged, firms, wide, sin, carbonyl, crossover,
# Nearest to have: although, flooded, married, bite, relaxed, impermeable, following, coats,
# Nearest to american: army, bursting, visits, irreversible, flexible, tesla, syria, residences,
# Nearest to hold: team, possibly, sites, explains, recalcitrant, independence, thompson, murdered,
# Nearest to channel: alamanni, subatomic, purely, toads, embarrassing, elgamal, tracked, kitchen,
# Nearest to universe: status, along, roach, inroads, comprehensive, welfare, confers, lip,
# Nearest to report: indeed, rips, tariffs, axel, projector, wander, asians, strategically,
# Nearest to orthodox: nder, competing, inanimate, anastasia, occasionally, midianites, turkish, chopstick,
# Nearest to proposed: bret, thanking, affects, ceasefire, repaired, baron, improve, haig,
# Nearest to issue: adherents, tenets, taxation, transition, japheth, twice, impacted, encouraging,
# Nearest to pope: anise, accord, thinly, seduced, shall, supergravity, tired, accept,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9265 0.0660 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9157 0.0654 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8742 0.0657 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8737 0.0656 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8089 0.0655 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8260 0.0655 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7947 0.0656 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7998 0.0655 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7750 0.0656 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7594 0.0658 sec/batch
# Nearest to not: enhance, days, nemours, cases, nes, fulfil, fergus, doped,
# Nearest to there: contemporaries, humiliating, deals, bears, eukaryotes, anymore, hemispheres, euclidean,
# Nearest to many: consolidate, cash, humanity, dissolves, blueberry, furious, apical, plumage,
# Nearest to three: event, martial, bay, diego, eight, altitude, min, atlases,
# Nearest to b: possessed, supervillain, drummer, k, kegan, structure, voraciously, nine,
# Nearest to but: beery, referees, wide, sin, firms, carbonyl, relied, engaged,
# Nearest to have: although, flooded, relaxed, bite, impermeable, thornton, zondervan, married,
# Nearest to american: army, bursting, visits, irreversible, residences, tesla, syria, outskirts,
# Nearest to hold: team, possibly, explains, sites, recalcitrant, independence, nick, murdered,
# Nearest to channel: subatomic, alamanni, tracked, embarrassing, toads, multiplied, purely, kitchen,
# Nearest to universe: roach, status, welfare, inroads, lip, observatory, along, confers,
# Nearest to report: tariffs, rips, indeed, projector, axel, strategically, wander, asians,
# Nearest to orthodox: inanimate, anastasia, nder, turkish, merging, competing, pragmatic, midianites,
# Nearest to proposed: ceasefire, bret, repaired, thanking, haig, luther, affects, discussion,
# Nearest to issue: tenets, adherents, taxation, transition, impacted, abused, japheth, hip,
# Nearest to pope: thinly, anise, accord, shall, seduced, offices, accept, tired,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7949 0.0663 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7755 0.0657 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7173 0.0661 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7052 0.0657 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7479 0.0659 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6982 0.0659 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7096 0.0661 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7319 0.0656 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6934 0.0655 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6449 0.0659 sec/batch
# Nearest to not: enhance, cases, fulfil, cbt, nes, nemours, doped, stakeholders,
# Nearest to there: contemporaries, humiliating, deals, kinsmen, eukaryotes, armband, anymore, exists,
# Nearest to many: cash, consolidate, humanity, dissolves, blueberry, furious, demesne, ventures,
# Nearest to three: eight, two, diego, six, event, martial, births, bay,
# Nearest to b: nine, drummer, supervillain, musician, voraciously, nlt, kegan, shipman,
# Nearest to but: beery, carbonyl, referees, relied, xps, engaged, simultaneous, surpassed,
# Nearest to have: although, flooded, relaxed, bite, thornton, zondervan, impermeable, kirghiz,
# Nearest to american: army, bursting, eight, novelist, william, outskirts, guitarist, visits,
# Nearest to hold: team, possibly, explains, sites, independence, displacements, recalcitrant, rectifier,
# Nearest to channel: subatomic, alamanni, tracked, mercantilism, embarrassing, toads, purely, elgamal,
# Nearest to universe: roach, welfare, status, confers, inroads, observatory, waller, lip,
# Nearest to report: tariffs, rips, projector, indeed, axel, strategically, asians, perish,
# Nearest to orthodox: inanimate, anastasia, turkish, nder, pragmatic, competing, merging, brainstorming,
# Nearest to proposed: ceasefire, repaired, bret, thanking, haig, sublime, silty, yalta,
# Nearest to issue: tenets, adherents, impacted, taxation, japheth, abused, eleventh, transition,
# Nearest to pope: thinly, anise, padres, shall, seduced, accord, accept, doggy,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6689 0.0666 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6837 0.0654 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.5903 0.0660 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6046 0.0660 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6288 0.0656 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6188 0.0657 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5927 0.0482 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5509 0.0658 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5161 0.0661 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4934 0.0659 sec/batch
# Nearest to not: enhance, cases, cbt, fulfil, stakeholders, omnipotent, vignettes, doped,
# Nearest to there: humiliating, contemporaries, kinsmen, armband, deals, eukaryotes, medicines, anymore,
# Nearest to many: cash, consolidate, demesne, humanity, recollections, blueberry, dissolves, furious,
# Nearest to three: eight, two, diego, six, aqueducts, event, hectares, alcock,
# Nearest to b: nine, musician, drummer, singer, one, statesman, anderson, physicist,
# Nearest to but: beery, carbonyl, xps, relied, referees, meaninglessness, engaged, wide,
# Nearest to have: although, relaxed, flooded, bite, thornton, impermeable, kirghiz, much,
# Nearest to american: novelist, guitarist, army, william, actress, bursting, eight, parenthood,
# Nearest to hold: team, explains, possibly, sites, displacements, recalcitrant, murdered, rectifier,
# Nearest to channel: subatomic, alamanni, tracked, purely, mercantilism, elgamal, toads, tuareg,
# Nearest to universe: roach, welfare, confers, inroads, waller, pulley, logarithmic, lip,
# Nearest to report: tariffs, rips, indeed, projector, asians, perish, wander, recognising,
# Nearest to orthodox: anastasia, turkish, inanimate, midianites, nder, parlement, brainstorming, pragmatic,
# Nearest to proposed: repaired, ceasefire, bret, thanking, haig, discussion, willers, loadable,
# Nearest to issue: tenets, adherents, abused, impacted, taxation, japheth, forlorn, encouraging,
# Nearest to pope: padres, thinly, seduced, shall, doggy, anise, gaetana, accord,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4982 0.0663 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4743 0.0660 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4397 0.0657 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5171 0.0660 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4812 0.0658 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4825 0.0659 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4501 0.0658 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4090 0.0659 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4495 0.0660 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4204 0.0662 sec/batch
# Nearest to not: cases, enhance, suffice, cbt, fulfil, orderly, omnipotent, stakeholders,
# Nearest to there: humiliating, contemporaries, armband, deals, anymore, eukaryotes, exists, kinsmen,
# Nearest to many: cash, demesne, humanity, consolidate, recollections, blueberry, licking, backronym,
# Nearest to three: two, eight, diego, six, aqueducts, hectares, balcony, isps,
# Nearest to b: k, drummer, musician, supervillain, kegan, anderson, nlt, ltcm,
# Nearest to but: carbonyl, xps, relied, beery, sin, wide, peat, yourselves,
# Nearest to have: although, relaxed, flooded, bite, inference, kirghiz, partnerships, impermeable,
# Nearest to american: army, novelist, guitarist, guevara, nantes, outskirts, parenthood, bursting,
# Nearest to hold: explains, team, possibly, sites, displacements, recalcitrant, rectifier, independence,
# Nearest to channel: subatomic, tracked, alamanni, toads, purely, elgamal, pardons, mercantilism,
# Nearest to universe: roach, confers, welfare, logarithmic, inroads, naturalistic, waller, pulley,
# Nearest to report: tariffs, rips, projector, indeed, asians, quirin, wander, recognising,
# Nearest to orthodox: anastasia, turkish, midianites, inanimate, church, parlement, catholic, brainstorming,
# Nearest to proposed: repaired, ceasefire, thanking, bret, discussion, loadable, willers, affects,
# Nearest to issue: tenets, adherents, abused, impacted, taxation, forlorn, japheth, bypassing,
# Nearest to pope: thinly, shall, padres, seduced, iii, doggy, son, accord,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4136 0.0668 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4208 0.0660 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4650 0.0658 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3977 0.0662 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4136 0.0659 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4432 0.0661 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3673 0.0660 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3900 0.0661 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4086 0.0657 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3644 0.0659 sec/batch
# Nearest to not: suffice, fulfil, cases, mohiam, enhance, cbt, omnipotent, orderly,
# Nearest to there: humiliating, contemporaries, exists, deals, armband, kinsmen, eukaryotes, neurotransmitters,
# Nearest to many: cash, demesne, clarion, consolidate, recollections, necessitates, humanity, backronym,
# Nearest to three: two, eight, six, aqueducts, diego, isps, hectares, min,
# Nearest to b: k, drummer, musician, anderson, supervillain, kegan, asin, revues,
# Nearest to but: xps, carbonyl, beery, referees, simultaneous, relied, peat, engaged,
# Nearest to have: although, relaxed, flooded, flaws, inference, partnerships, much, bite,
# Nearest to american: novelist, army, guitarist, outskirts, guevara, nantes, actress, rican,
# Nearest to hold: explains, possibly, team, sites, recalcitrant, displacements, rectifier, jamil,
# Nearest to channel: subatomic, toads, elgamal, tracked, purely, dts, oppidum, pardons,
# Nearest to universe: roach, logarithmic, confers, naturalistic, lip, giedi, pulley, hydronium,
# Nearest to report: tariffs, projector, rips, indeed, quirin, asians, recognising, strands,
# Nearest to orthodox: church, turkish, anastasia, parlement, catholic, christian, churches, midianites,
# Nearest to proposed: repaired, thanking, ceasefire, discussion, loadable, affects, bret, willers,
# Nearest to issue: adherents, tenets, abused, impacted, taxation, forlorn, eschews, historiographer,
# Nearest to pope: thinly, shall, padres, iii, son, accord, gaetana, seduced,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3657 0.0666 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3786 0.0655 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3687 0.0657 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3529 0.0657 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4154 0.0656 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3563 0.0659 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3622 0.0660 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3881 0.0657 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3317 0.0659 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3390 0.0659 sec/batch
# Nearest to not: cases, fulfil, suffice, orderly, enhance, cbt, mohiam, harmful,
# Nearest to there: humiliating, exists, kinsmen, contemporaries, euclidean, deals, armband, anymore,
# Nearest to many: cash, demesne, recollections, humanity, clarion, consolidate, backronym, bolus,
# Nearest to three: two, eight, six, aqueducts, isps, hectares, min, rate,
# Nearest to b: k, drummer, musician, differentiable, anderson, ltcm, vegeta, asin,
# Nearest to but: xps, beery, carbonyl, resurrect, relied, peat, heartfelt, unless,
# Nearest to have: although, relaxed, flaws, much, flooded, does, inference, censuses,
# Nearest to american: army, novelist, guevara, outskirts, guitarist, nantes, rican, parenthood,
# Nearest to hold: team, explains, possibly, sites, recalcitrant, independence, displacements, jamil,
# Nearest to channel: toads, elgamal, subatomic, tracked, leela, oppidum, dts, purely,
# Nearest to universe: roach, logarithmic, naturalistic, confers, hydronium, pulley, giedi, observatory,
# Nearest to report: tariffs, projector, quirin, wilmot, indeed, rips, recognising, shockley,
# Nearest to orthodox: church, catholic, parlement, turkish, christian, orthodoxy, theodosius, churches,
# Nearest to proposed: thanking, ceasefire, repaired, loadable, discussion, affects, bret, gravitons,
# Nearest to issue: adherents, taxation, tenets, abused, impacted, forlorn, encouraging, eschews,
# Nearest to pope: shall, thinly, iii, accord, seduced, liturgy, accept, son,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3334 0.0666 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2835 0.0660 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3696 0.0654 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3601 0.0656 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3564 0.0656 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2887 0.0658 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3055 0.0654 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3307 0.0659 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2196 0.0657 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3286 0.0657 sec/batch
# Nearest to not: enhance, suffice, orderly, cases, fulfil, cbt, harmful, anthropomorphism,
# Nearest to there: humiliating, exists, surf, armband, kinsmen, contemporaries, deals, euclidean,
# Nearest to many: cash, recollections, demesne, clarion, blueberry, backronym, masonry, necessitates,
# Nearest to three: two, eight, six, zero, aqueducts, seven, births, four,
# Nearest to b: k, drummer, one, statesman, nine, musician, d, anderson,
# Nearest to but: xps, beery, resurrect, heartfelt, peat, dubious, simultaneous, relied,
# Nearest to have: although, relaxed, flaws, much, censuses, partnerships, flooded, thornton,
# Nearest to american: novelist, guevara, guitarist, wilbur, rican, nantes, jimmie, actress,
# Nearest to hold: explains, possibly, team, displacements, recalcitrant, conferred, sites, jamil,
# Nearest to channel: toads, tracked, elgamal, oppidum, subatomic, leela, mercantilism, dts,
# Nearest to universe: roach, naturalistic, confers, logarithmic, hydronium, giedi, pulley, lip,
# Nearest to report: tariffs, quirin, projector, recognising, rips, shockley, guin, benefitting,
# Nearest to orthodox: orthodoxy, theodosius, parlement, midianites, churches, church, catholic, turkish,
# Nearest to proposed: ceasefire, thanking, repaired, loadable, affects, haig, prejudice, discussion,
# Nearest to issue: tenets, adherents, taxation, abused, impacted, forlorn, volap, eschews,
# Nearest to pope: shall, iii, thinly, pius, seduced, liturgy, padres, gaetana,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2985 0.0664 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3094 0.0656 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3407 0.0304 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2365 0.0659 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2483 0.0658 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2413 0.0657 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1862 0.0657 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1828 0.0660 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2304 0.0658 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1879 0.0656 sec/batch
# Nearest to not: orderly, cases, fulfil, enhance, suffice, anthropomorphism, going, isadore,
# Nearest to there: humiliating, armband, surf, kinsmen, any, contemporaries, anymore, gens,
# Nearest to many: cash, recollections, blueberry, necessitates, masonry, demesne, licking, clarion,
# Nearest to three: two, eight, six, zero, min, aqueducts, four, rate,
# Nearest to b: k, drummer, ltcm, statesman, musician, kegan, one, d,
# Nearest to but: xps, peat, resurrect, relied, simultaneous, beery, carbonyl, panda,
# Nearest to have: relaxed, although, flaws, censuses, sterilizing, much, flooded, colonialist,
# Nearest to american: guevara, rican, guitarist, novelist, parenthood, nantes, wilbur, hays,
# Nearest to hold: explains, team, possibly, recalcitrant, displacements, independence, jamil, conferred,
# Nearest to channel: toads, elgamal, subatomic, tracked, dts, leela, oppidum, equipment,
# Nearest to universe: naturalistic, roach, confers, hydronium, logarithmic, existence, giedi, pulley,
# Nearest to report: tariffs, quirin, guin, hilltops, projector, wilmot, rips, benefitting,
# Nearest to orthodox: theodosius, orthodoxy, churches, parlement, midianites, church, catholic, anastasia,
# Nearest to proposed: ceasefire, thanking, repaired, prejudice, loadable, willers, haig, discussion,
# Nearest to issue: taxation, tenets, impacted, adherents, abused, volap, eschews, forlorn,
# Nearest to pope: iii, shall, pius, seduced, thinly, liturgy, mieszko, satavahana,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2492 0.0667 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2349 0.0660 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2235 0.0662 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1349 0.0660 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1742 0.0659 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.2045 0.0661 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1604 0.0657 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1717 0.0660 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2188 0.0660 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.2141 0.0659 sec/batch
# Nearest to not: orderly, suffice, fulfil, enhance, stakeholders, cases, harmful, going,
# Nearest to there: humiliating, exists, surf, armband, euclidean, gens, any, contemporaries,
# Nearest to many: cash, recollections, necessitates, masonry, blueberry, clarion, demesne, backronym,
# Nearest to three: two, eight, six, zero, four, min, aqueducts, rate,
# Nearest to b: k, differentiable, ltcm, vegeta, y, tangent, kegan, integers,
# Nearest to but: xps, beery, peat, resurrect, relied, unless, carbonyl, heartfelt,
# Nearest to have: relaxed, although, flaws, sterilizing, much, censuses, bite, colonialist,
# Nearest to american: guevara, parenthood, outskirts, rican, army, nantes, hays, kirkland,
# Nearest to hold: explains, team, possibly, displacements, sites, asic, recalcitrant, conferred,
# Nearest to channel: toads, elgamal, tracked, dts, oppidum, anastasio, fm, fluctuating,
# Nearest to universe: naturalistic, roach, hydronium, confers, logarithmic, pulley, giedi, novel,
# Nearest to report: tariffs, quirin, nuclear, guin, wilmot, recognising, benefitting, hilltops,
# Nearest to orthodox: churches, theodosius, orthodoxy, catholic, parlement, christian, church, congregational,
# Nearest to proposed: thanking, loadable, affects, discussion, prejudice, pel, ceasefire, gravitons,
# Nearest to issue: impacted, adherents, tenets, taxation, abused, volap, eschews, encouraging,
# Nearest to pope: iii, shall, pius, seduced, liturgy, thinly, papal, subduing,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1651 0.0669 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2255 0.0661 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1851 0.0683 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1377 0.0669 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1924 0.0662 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2083 0.0661 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1826 0.0661 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1870 0.0656 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1253 0.0656 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1843 0.0661 sec/batch
# Nearest to not: orderly, fulfil, stakeholders, harmful, violate, anthropomorphism, enhance, suffice,
# Nearest to there: humiliating, gens, armband, exists, kinsmen, surf, anymore, any,
# Nearest to many: cash, recollections, masonry, demesne, blueberry, necessitates, humanity, clarion,
# Nearest to three: two, eight, six, zero, four, seven, rate, one,
# Nearest to b: k, ltcm, ulf, kegan, drummer, ohm, asin, shipman,
# Nearest to but: xps, resurrect, beery, peat, relied, plurals, carbonyl, heartfelt,
# Nearest to have: relaxed, although, flaws, sterilizing, censuses, much, colonialist, bite,
# Nearest to american: guevara, parenthood, rican, hays, guitarist, novelist, army, jimmie,
# Nearest to hold: explains, team, possibly, asic, recalcitrant, displacements, forced, conferred,
# Nearest to channel: toads, elgamal, oppidum, fm, dts, tracked, anastasio, equipment,
# Nearest to universe: naturalistic, roach, hydronium, confers, novel, giedi, logarithmic, existence,
# Nearest to report: tariffs, nuclear, guin, quirin, recognising, memo, shockley, spy,
# Nearest to orthodox: churches, theodosius, orthodoxy, catholic, parlement, church, congregational, midianites,
# Nearest to proposed: thanking, affects, loadable, ceasefire, gravitons, willers, haig, repaired,
# Nearest to issue: impacted, taxation, abused, adherents, tenets, eschews, volap, forlorn,
# Nearest to pope: pius, shall, iii, seduced, thinly, liturgy, taika, antipope,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1858 0.0668 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1804 0.0661 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1869 0.0659 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2265 0.0662 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1310 0.0662 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1199 0.0659 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1691 0.0660 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1163 0.0659 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1957 0.0659 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1963 0.0659 sec/batch
# Nearest to not: orderly, violate, fulfil, stakeholders, cases, anthropomorphism, harmful, warez,
# Nearest to there: humiliating, kinsmen, gens, any, exists, armband, anymore, surf,
# Nearest to many: cash, recollections, demesne, masonry, clarion, consolidate, trend, backronym,
# Nearest to three: two, eight, six, zero, four, one, five, seven,
# Nearest to b: k, ulf, drummer, cellist, shipman, nine, ltcm, asin,
# Nearest to but: xps, beery, resurrect, relied, peat, unless, plurals, unfriendly,
# Nearest to have: relaxed, although, flaws, censuses, sterilizing, much, colonialist, abolitionists,
# Nearest to american: rican, guevara, actress, guitarist, novelist, hays, dancer, cricketer,
# Nearest to hold: team, explains, possibly, recalcitrant, independence, conferred, displacements, wentworth,
# Nearest to channel: fm, dts, toads, elgamal, anastasio, oppidum, tracked, equipment,
# Nearest to universe: naturalistic, hydronium, confers, roach, giedi, observatory, pulley, novel,
# Nearest to report: tariffs, quirin, nuclear, memo, recognising, directories, hilltops, spy,
# Nearest to orthodox: churches, theodosius, orthodoxy, midianites, congregational, church, parlement, mainline,
# Nearest to proposed: ceasefire, prejudice, thanking, affects, loadable, gravitons, pel, haig,
# Nearest to issue: impacted, taxation, volap, abused, forlorn, eschews, adherents, bypassing,
# Nearest to pope: pius, shall, iii, seduced, antipope, liturgy, papal, subduing,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2163 0.0665 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1245 0.0658 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1263 0.0658 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1374 0.0655 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0579 0.0653 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1711 0.0657 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1514 0.0658 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1326 0.0657 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1897 0.0125 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1301 0.0660 sec/batch
# Nearest to not: orderly, harmful, going, enhance, violate, stakeholders, t, anthropomorphism,
# Nearest to there: humiliating, any, armband, kinsmen, surf, anymore, gens, rke,
# Nearest to many: cash, masonry, recollections, demesne, trend, necessitates, clarion, sweepers,
# Nearest to three: two, eight, six, zero, four, one, five, seven,
# Nearest to b: k, ulf, cellist, statesman, drummer, ltcm, asin, oceanographer,
# Nearest to but: xps, beery, peat, relied, plurals, unless, resurrect, unfriendly,
# Nearest to have: relaxed, although, sterilizing, flaws, censuses, much, bite, partnerships,
# Nearest to american: rican, guevara, hays, novelist, dancer, kirkland, actress, parenthood,
# Nearest to hold: team, explains, possibly, recalcitrant, displacements, independence, conferred, asic,
# Nearest to channel: fm, dts, elgamal, anastasio, toads, oppidum, tracked, liberec,
# Nearest to universe: confers, naturalistic, hydronium, novel, giedi, utter, roach, metabolize,
# Nearest to report: tariffs, quirin, memo, nuclear, directories, spy, hilltops, recognising,
# Nearest to orthodox: churches, orthodoxy, midianites, parlement, theodosius, congregational, anastasia, mainline,
# Nearest to proposed: ceasefire, affects, prejudice, thanking, loadable, gravitons, haig, willers,
# Nearest to issue: impacted, volap, forlorn, abused, eschews, taxation, bypassing, encouraging,
# Nearest to pope: pius, shall, iii, seduced, antipope, papal, taika, subduing,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0859 0.0665 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0927 0.0662 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0960 0.0658 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0878 0.0657 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0729 0.0657 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0111 0.0656 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0891 0.0662 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0824 0.0656 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1280 0.0658 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0286 0.0658 sec/batch
# Nearest to not: orderly, going, harmful, couldn, violate, isadore, humiliating, homophobic,
# Nearest to there: humiliating, any, armband, anymore, gens, surf, kinsmen, rke,
# Nearest to many: masonry, cash, demesne, trend, recollections, necessitates, byword, sweepers,
# Nearest to three: two, eight, six, zero, four, five, seven, one,
# Nearest to b: k, differentiable, ltcm, ohm, vegeta, verit, integers, hertz,
# Nearest to but: xps, beery, peat, relied, unless, plurals, resurrect, unfriendly,
# Nearest to have: relaxed, although, sterilizing, flaws, censuses, much, bite, colonialist,
# Nearest to american: guevara, rican, parenthood, jacobin, hays, nantes, kirkland, dancer,
# Nearest to hold: team, explains, possibly, recalcitrant, independence, wentworth, conferred, nick,
# Nearest to channel: dts, fm, anastasio, toads, elgamal, oppidum, simms, equipment,
# Nearest to universe: naturalistic, hydronium, confers, novel, roach, metabolize, giedi, pulley,
# Nearest to report: memo, quirin, nuclear, tariffs, hilltops, directories, spy, gasket,
# Nearest to orthodox: churches, orthodoxy, theodosius, midianites, congregational, anastasia, catholic, parlement,
# Nearest to proposed: affects, ceasefire, prejudice, gravitons, thanking, loadable, repaired, luther,
# Nearest to issue: impacted, volap, forlorn, bypassing, encouraging, adherents, abused, eschews,
# Nearest to pope: pius, iii, shall, antipope, seduced, papal, liturgy, anjou,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0423 0.0669 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0467 0.0661 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0250 0.0660 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0533 0.0662 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0703 0.0663 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0299 0.0659 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0618 0.0664 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1010 0.0662 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0542 0.0662 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0436 0.0660 sec/batch
# Nearest to not: humiliating, homophobic, harmful, orderly, going, fulfil, violate, couldn,
# Nearest to there: any, humiliating, anymore, euclidean, definition, exists, median, gens,
# Nearest to many: cash, demesne, masonry, clarion, trend, recollections, necessitates, most,
# Nearest to three: two, eight, six, zero, four, five, one, seven,
# Nearest to b: k, ltcm, ohm, cellist, oceanographer, differentiable, ulf, verit,
# Nearest to but: xps, beery, unless, unfriendly, relied, carbonyl, peat, plurals,
# Nearest to have: relaxed, although, sterilizing, flaws, censuses, partnerships, colonialist, bite,
# Nearest to american: guevara, rican, hays, parenthood, nantes, kirkland, jacobin, dancer,
# Nearest to hold: team, explains, wentworth, possibly, recalcitrant, regnant, forced, conferred,
# Nearest to channel: dts, fm, anastasio, toads, elgamal, oppidum, kitchen, pictish,
# Nearest to universe: naturalistic, confers, hydronium, novum, pulley, roach, utter, prophetically,
# Nearest to report: memo, nuclear, quirin, tariffs, spy, hilltops, http, gasket,
# Nearest to orthodox: churches, orthodoxy, theodosius, congregational, midianites, catholic, anastasia, brainstorming,
# Nearest to proposed: affects, gravitons, thanking, prejudice, loadable, ceasefire, willers, pel,
# Nearest to issue: impacted, forlorn, volap, adherents, declaring, abused, taxation, borden,
# Nearest to pope: pius, shall, papal, antipope, iii, seduced, liturgy, subduing,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0388 0.0674 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0808 0.0660 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0532 0.0658 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0807 0.0659 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0627 0.0659 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0558 0.0660 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0738 0.0658 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0346 0.0658 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0679 0.0657 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0615 0.0662 sec/batch
# Nearest to not: orderly, fulfil, going, harmful, humiliating, stakeholders, warez, violate,
# Nearest to there: humiliating, any, gens, anymore, armband, kinsmen, rke, definition,
# Nearest to many: cash, masonry, trend, recollections, clarion, demesne, most, necessitates,
# Nearest to three: two, eight, six, zero, four, seven, one, five,
# Nearest to b: k, ltcm, cellist, oceanographer, ohm, differentiable, drummer, speculator,
# Nearest to but: xps, beery, unfriendly, relied, peat, unless, resurrect, plurals,
# Nearest to have: relaxed, although, censuses, flaws, sterilizing, partnerships, colonialist, thornton,
# Nearest to american: guevara, parenthood, rican, jacobin, kirkland, hays, nantes, alejandro,
# Nearest to hold: team, explains, wentworth, conferred, independence, recalcitrant, asic, regnant,
# Nearest to channel: dts, anastasio, fm, toads, tv, elgamal, oppidum, kitchen,
# Nearest to universe: naturalistic, confers, hydronium, giedi, utter, novum, roach, existence,
# Nearest to report: memo, nuclear, quirin, tariffs, editorial, spy, hilltops, http,
# Nearest to orthodox: churches, theodosius, orthodoxy, catholic, midianites, congregational, anastasia, church,
# Nearest to proposed: thanking, affects, haig, ceasefire, prejudice, gravitons, willers, loadable,
# Nearest to issue: impacted, forlorn, adherents, volap, bypassing, borden, eschews, abused,
# Nearest to pope: pius, iii, shall, papal, antipope, seduced, subduing, liturgy,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0749 0.0669 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0190 0.0659 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0671 0.0662 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0674 0.0662 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0699 0.0661 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1223 0.0661 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1460 0.0661 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0213 0.0661 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9989 0.0658 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0693 0.0659 sec/batch
# Nearest to not: warez, harmful, redirected, going, referencing, fulfil, stakeholders, we,
# Nearest to there: any, humiliating, anymore, rke, median, mafioso, gens, surf,
# Nearest to many: cash, trend, masonry, recollections, clarion, sweepers, demesne, necessitates,
# Nearest to three: two, eight, six, zero, four, one, five, seven,
# Nearest to b: k, ltcm, cellist, drummer, wanda, bawerk, shipman, tortelli,
# Nearest to but: beery, xps, unfriendly, peat, unless, relied, simultaneous, plurals,
# Nearest to have: relaxed, although, censuses, sterilizing, partnerships, flaws, in, colonialist,
# Nearest to american: guevara, jacobin, rican, parenthood, kirkland, hays, actress, alejandro,
# Nearest to hold: explains, wentworth, team, conferred, possibly, independence, regnant, recalcitrant,
# Nearest to channel: dts, fm, elgamal, anastasio, toads, tv, kitchen, oppidum,
# Nearest to universe: naturalistic, confers, utter, abilities, novum, giedi, existence, prophetically,
# Nearest to report: memo, nuclear, quirin, spy, tariffs, hilltops, editorial, journal,
# Nearest to orthodox: theodosius, orthodoxy, churches, anastasia, midianites, kislev, mainline, congregational,
# Nearest to proposed: thanking, affects, haig, gravitons, prejudice, ceasefire, loadable, willers,
# Nearest to issue: impacted, forlorn, borden, bypassing, volap, restraining, abused, eschews,
# Nearest to pope: pius, antipope, iii, papal, shall, seduced, schism, subduing,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9882 0.0665 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0472 0.0657 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0461 0.0656 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0435 0.0658 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0748 0.0658 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0460 0.0606 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0056 0.0655 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0057 0.0658 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0108 0.0655 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9762 0.0659 sec/batch
# Nearest to not: going, couldn, referencing, redirected, perceptual, t, we, anthropomorphism,
# Nearest to there: any, humiliating, rke, anymore, gens, mafioso, definition, surf,
# Nearest to many: masonry, most, recollections, trend, cash, sweepers, highly, demesne,
# Nearest to three: two, eight, six, zero, four, one, five, seven,
# Nearest to b: nine, ltcm, drummer, player, scalia, k, bawerk, troughton,
# Nearest to but: beery, xps, peat, unfriendly, relied, unless, plurals, panda,
# Nearest to have: although, relaxed, sterilizing, censuses, in, flaws, tongues, the,
# Nearest to american: guevara, parenthood, jacobin, dancer, actress, rican, alejandro, kirkland,
# Nearest to hold: explains, team, wentworth, conferred, possibly, asic, independence, familiarity,
# Nearest to channel: dts, fm, anastasio, elgamal, toads, tv, oppidum, wilmslow,
# Nearest to universe: confers, naturalistic, utter, abilities, hydronium, novum, existence, giedi,
# Nearest to report: memo, nuclear, editorial, quirin, journal, spy, floodgates, http,
# Nearest to orthodox: orthodoxy, theodosius, anastasia, churches, midianites, kislev, mainline, parlement,
# Nearest to proposed: thanking, affects, haig, gravitons, willers, ceasefire, prejudice, luther,
# Nearest to issue: impacted, forlorn, borden, bypassing, restraining, eschews, penicillium, transition,
# Nearest to pope: pius, antipope, papal, iii, shall, schism, seduced, boniface,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9966 0.0665 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9230 0.0658 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0197 0.0657 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0026 0.0663 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0241 0.0662 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9899 0.0661 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9171 0.0665 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9601 0.0660 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9495 0.0662 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9636 0.0662 sec/batch
# Nearest to not: going, we, couldn, that, homophobic, humiliating, t, warez,
# Nearest to there: any, median, humiliating, rke, anymore, definition, mafioso, gens,
# Nearest to many: masonry, most, trend, cash, recollections, clarion, demesne, highly,
# Nearest to three: two, eight, six, zero, four, five, one, nine,
# Nearest to b: k, ltcm, differentiable, conformations, drummer, ohm, integers, speculator,
# Nearest to but: xps, beery, unfriendly, unless, peat, again, plurals, relied,
# Nearest to have: although, relaxed, in, though, censuses, sterilizing, the, tongues,
# Nearest to american: guevara, jacobin, parenthood, alejandro, rican, states, dancer, nantes,
# Nearest to hold: explains, team, conferred, wentworth, asic, inelegant, independence, slabs,
# Nearest to channel: dts, fm, anastasio, tv, elgamal, pictish, oppidum, alamanni,
# Nearest to universe: hydronium, naturalistic, pulley, confers, existence, metabolize, generalise, utter,
# Nearest to report: memo, nuclear, quirin, floodgates, editorial, spy, gov, broadside,
# Nearest to orthodox: orthodoxy, theodosius, churches, anastasia, midianites, catholic, kislev, congregational,
# Nearest to proposed: affects, thanking, gravitons, haig, willers, ceasefire, abm, testable,
# Nearest to issue: impacted, forlorn, eschews, borden, restraining, bypassing, consubstantiation, mika,
# Nearest to pope: pius, papal, antipope, shall, iii, schism, liturgy, seduced,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9872 0.0669 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0314 0.0663 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9666 0.0659 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0270 0.0661 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0232 0.0657 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9528 0.0662 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9956 0.0659 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9845 0.0660 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9757 0.0658 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0014 0.0656 sec/batch
# Nearest to not: going, that, referencing, we, humiliating, perceptual, nanotech, fulfil,
# Nearest to there: any, rke, humiliating, anymore, gens, surf, definition, median,
# Nearest to many: most, trend, masonry, sweepers, recollections, demesne, cash, clarion,
# Nearest to three: two, eight, six, zero, four, one, five, nine,
# Nearest to b: troughton, k, bawerk, oceanographer, ltcm, drummer, shipman, wanda,
# Nearest to but: beery, xps, unfriendly, peat, unless, plurals, relied, resurrect,
# Nearest to have: although, in, relaxed, censuses, sterilizing, though, clocked, been,
# Nearest to american: guevara, actress, jacobin, kirkland, alejandro, rican, novelist, parenthood,
# Nearest to hold: wentworth, team, conferred, explains, independence, asic, possibly, inelegant,
# Nearest to channel: tv, dts, fm, anastasio, elgamal, broadcasting, pictish, toads,
# Nearest to universe: naturalistic, confers, hydronium, pulley, giedi, novum, existence, generalise,
# Nearest to report: memo, nuclear, floodgates, quirin, spy, editorial, gov, tariffs,
# Nearest to orthodox: orthodoxy, churches, theodosius, christian, congregational, kislev, anastasia, catholic,
# Nearest to proposed: affects, thanking, gravitons, haig, willers, testable, pel, abm,
# Nearest to issue: forlorn, borden, impacted, restraining, eschews, declaring, adherents, consubstantiation,
# Nearest to pope: pius, papal, antipope, schism, shall, iii, liturgy, boniface,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9971 0.0665 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9526 0.0660 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9640 0.0658 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9853 0.0659 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0191 0.0661 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0254 0.0661 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9747 0.0664 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9555 0.0667 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9403 0.0671 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0153 0.0673 sec/batch
# Nearest to not: that, going, we, t, nanotech, homophobic, couldn, implies,
# Nearest to there: any, rke, humiliating, removes, anymore, exists, definition, mafioso,
# Nearest to many: most, trend, masonry, recollections, sweepers, demesne, cash, plumage,
# Nearest to three: two, eight, six, zero, five, four, one, nine,
# Nearest to b: k, ltcm, bawerk, drummer, wanda, textrm, troughton, shipman,
# Nearest to but: beery, unfriendly, xps, peat, plurals, unless, relied, panda,
# Nearest to have: although, in, censuses, relaxed, been, the, that, though,
# Nearest to american: guevara, actress, jacobin, alejandro, kirkland, novelist, rican, parenthood,
# Nearest to hold: conferred, wentworth, team, independence, asic, inelegant, explains, slabs,
# Nearest to channel: dts, tv, fm, anastasio, broadcasting, elgamal, subatomic, embarrassing,
# Nearest to universe: confers, naturalistic, hydronium, generalise, existence, novum, pulley, giedi,
# Nearest to report: memo, nuclear, quirin, editorial, floodgates, spy, gov, tariffs,
# Nearest to orthodox: orthodoxy, churches, theodosius, kislev, anastasia, midianites, authenticated, congregational,
# Nearest to proposed: affects, thanking, haig, gravitons, prejudice, willers, pel, testable,
# Nearest to issue: forlorn, borden, restraining, impacted, eschews, declaring, bypassing, mika,
# Nearest to pope: pius, papal, antipope, schism, shall, liturgy, iii, boniface,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9869 0.0680 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.1096 0.0672 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0281 0.0668 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0220 0.0658 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9433 0.0661 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9374 0.0656 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 4.0041 0.0658 sec/batch
# ...
# Nearest to b: manush, conformations, hairstyle, shevchenko, mattingly, hendrick, textrm, economist,
# Nearest to but: to, that, again, not, with, relied, it, unfriendly,
# Nearest to have: been, in, has, the, though, there, although, are,
# Nearest to american: british, actress, states, novelist, bulmer, songwriter, americans, guevara,
# Nearest to hold: penrose, wentworth, migrates, asic, prix, independence, monothelitism, slabs,
# Nearest to channel: dts, channels, manche, fluctuating, tv, oppidum, magnetic, embarrassing,
# Nearest to universe: metabolize, confers, prophetically, generalise, giedi, waller, existence, cosmological,
# Nearest to report: memo, foia, skies, medlineplus, personify, floodgates, newsletter, chronology,
# Nearest to orthodox: orthodoxy, kislev, anastasia, turkish, theodosius, authenticated, belarus, bracketed,
# Nearest to proposed: thanking, affects, sverdlovsk, testable, gravitons, officially, mortuary, edna,
# Nearest to issue: borden, forlorn, declaring, restraining, impacted, dissent, seen, aspartate,
# Nearest to pope: papal, antipope, pius, boniface, popes, innocent, sixtus, avignon,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8319 0.0668 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8861 0.0661 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8609 0.0659 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8609 0.0660 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8639 0.0662 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8715 0.0661 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8718 0.0663 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8461 0.0660 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.9036 0.0661 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8447 0.0660 sec/batch
# Nearest to not: that, but, did, couldn, their, although, referencing, as,
# Nearest to there: have, are, any, out, exaggeration, all, mafioso, to,
# Nearest to many: most, are, some, larger, masonry, highly, composed, as,
# Nearest to three: two, six, eight, zero, one, five, four, seven,
# Nearest to b: manush, conformations, bmod, shevchenko, textrm, economist, mattingly, scalia,
# Nearest to but: to, not, though, it, again, unfriendly, relied, with,
# Nearest to have: been, in, there, are, the, that, though, although,
# Nearest to american: british, states, actress, initialized, americans, songwriter, bulmer, jacobin,
# Nearest to hold: wentworth, asic, penrose, independence, migrates, bernadotte, yes, conferred,
# Nearest to channel: dts, fluctuating, manche, tv, channels, broadcasting, embarrassing, oppidum,
# Nearest to universe: confers, metabolize, prophetically, existence, generalise, waller, worlds, cosmological,
# Nearest to report: memo, foia, personify, skies, medlineplus, floodgates, afghans, newsletter,
# Nearest to orthodox: orthodoxy, kislev, anastasia, turkish, churches, authenticated, belarus, theodosius,
# Nearest to proposed: thanking, officially, affects, testable, sverdlovsk, gravitons, mortuary, lsch,
# Nearest to issue: borden, forlorn, declaring, restraining, dissent, seen, aspartate, impacted,
# Nearest to pope: papal, antipope, pius, boniface, popes, sixtus, innocent, avignon,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8487 0.0670 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8715 0.0661 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8378 0.0664 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8182 0.0662 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9008 0.0662 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8658 0.0664 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9746 0.0661 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8842 0.0660 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9217 0.0660 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8000 0.0659 sec/batch
# Nearest to not: that, did, couldn, but, referencing, although, t, they,
# Nearest to there: have, are, any, out, animistic, mafioso, rke, exaggeration,
# Nearest to many: most, some, are, as, larger, masonry, highly, popular,
# Nearest to three: two, six, eight, zero, one, five, four, seven,
# Nearest to b: manush, conformations, economist, scalia, aerodrome, shipman, textrm, hairstyle,
# Nearest to but: to, again, though, not, although, it, relied, unfriendly,
# Nearest to have: been, in, there, although, are, the, though, that,
# Nearest to american: actress, british, states, actor, songwriter, initialized, novelist, americans,
# Nearest to hold: wentworth, asic, penrose, independence, conferred, bernadotte, migrates, monothelitism,
# Nearest to channel: dts, fluctuating, manche, channels, tv, broadcasting, oppidum, embarrassing,
# Nearest to universe: confers, metabolize, waller, prophetically, generalise, giedi, existence, cosmological,
# Nearest to report: memo, foia, personify, floodgates, afghans, skies, medlineplus, interview,
# Nearest to orthodox: kislev, orthodoxy, anastasia, turkish, authenticated, belarus, bracketed, theodosius,
# Nearest to proposed: officially, thanking, affects, sverdlovsk, testable, mortuary, gravitons, lsch,
# Nearest to issue: forlorn, declaring, borden, restraining, blocking, aspartate, dissent, seen,
# Nearest to pope: papal, antipope, pius, boniface, popes, sixtus, innocent, schism,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7851 0.0665 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8797 0.0657 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8057 0.0660 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8769 0.0661 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8358 0.0660 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8600 0.0659 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8658 0.0375 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8180 0.0659 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8173 0.0660 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8280 0.0657 sec/batch
# Nearest to not: that, did, couldn, but, although, as, referencing, to,
# Nearest to there: have, any, are, out, mafioso, rke, exaggeration, is,
# Nearest to many: most, some, are, highly, as, masonry, popular, large,
# Nearest to three: two, one, eight, six, zero, five, four, seven,
# Nearest to b: manush, economist, d, mccormack, scalia, nine, shevchenko, hendrick,
# Nearest to but: to, it, unfriendly, not, although, again, do, their,
# Nearest to have: been, in, there, although, are, other, that, as,
# Nearest to american: actress, british, novelist, songwriter, actor, initialized, laureate, americans,
# Nearest to hold: wentworth, asic, penrose, migrates, bernadotte, conferred, independence, monothelitism,
# Nearest to channel: fluctuating, dts, manche, channels, broadcasting, tv, oppidum, ocean,
# Nearest to universe: confers, metabolize, waller, existence, prophetically, generalise, utter, giedi,
# Nearest to report: memo, foia, personify, chronology, medlineplus, skies, interview, clouds,
# Nearest to orthodox: kislev, orthodoxy, anastasia, turkish, authenticated, belarus, bracketed, underbelly,
# Nearest to proposed: thanking, officially, sverdlovsk, affects, willers, testable, monuc, gravitons,
# Nearest to issue: borden, forlorn, declaring, restraining, blocking, aspartate, dissent, cahiers,
# Nearest to pope: papal, antipope, pius, popes, boniface, innocent, avignon, sixtus,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8170 0.0667 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8245 0.0659 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8149 0.0658 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7889 0.0660 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8517 0.0660 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8541 0.0662 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8670 0.0662 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7584 0.0660 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8080 0.0662 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8034 0.0660 sec/batch
# Nearest to not: that, but, did, to, their, as, they, although,
# Nearest to there: are, any, have, out, is, all, rke, two,
# Nearest to many: most, are, some, as, in, were, highly, masonry,
# Nearest to three: two, zero, six, one, eight, five, four, seven,
# Nearest to b: manush, conformations, aerodrome, bmod, differentiable, hairstyle, transitivity, ltcm,
# Nearest to but: to, not, it, that, though, their, again, in,
# Nearest to have: been, in, are, though, the, there, be, other,
# Nearest to american: british, americans, states, actress, initialized, respective, cowboy, novelist,
# Nearest to hold: asic, penrose, wentworth, migrates, conferred, yes, slabs, ectoplasm,
# Nearest to channel: fluctuating, manche, embarrassing, channels, dts, broadcasting, tv, sometime,
# Nearest to universe: confers, metabolize, waller, generalise, fit, prophetically, hecate, existence,
# Nearest to report: memo, foia, personify, medlineplus, chronology, skies, newsletter, floodgates,
# Nearest to orthodox: kislev, orthodoxy, anastasia, turkish, authenticated, underbelly, bracketed, belarus,
# Nearest to proposed: thanking, officially, affects, sverdlovsk, gravitons, testable, willers, mortuary,
# Nearest to issue: borden, declaring, forlorn, restraining, aspartate, dissent, blocking, impacted,
# Nearest to pope: papal, antipope, pius, popes, boniface, innocent, soissons, avignon,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7589 0.0670 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8513 0.0664 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8481 0.0662 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8514 0.0664 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8213 0.0663 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8773 0.0662 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8591 0.0661 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8204 0.0658 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8089 0.0660 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8439 0.0660 sec/batch
# Nearest to not: that, but, as, did, their, to, although, already,
# Nearest to there: are, have, any, out, the, all, is, two,
# Nearest to many: most, are, some, as, were, in, there, highly,
# Nearest to three: two, six, zero, eight, one, five, four, nine,
# Nearest to b: manush, bmod, aerodrome, conformations, transitivity, hairstyle, ltcm, hendrick,
# Nearest to but: to, not, though, it, again, in, although, that,
# Nearest to have: been, in, are, there, be, though, has, although,
# Nearest to american: british, actress, americans, states, initialized, songwriter, novelist, laureate,
# Nearest to hold: asic, wentworth, migrates, penrose, monothelitism, bernadotte, independence, sinful,
# Nearest to channel: dts, fluctuating, channels, manche, embarrassing, sometime, tv, broadcasting,
# Nearest to universe: confers, metabolize, waller, generalise, prophetically, worlds, hecate, existence,
# Nearest to report: memo, foia, medlineplus, personify, chronology, newsletter, floodgates, skies,
# Nearest to orthodox: orthodoxy, kislev, eastern, churches, anastasia, turkish, authenticated, theodosius,
# Nearest to proposed: thanking, officially, sverdlovsk, affects, mortuary, testable, lsch, gravitons,
# Nearest to issue: borden, aspartate, dissent, forlorn, declaring, restraining, posed, blocking,
# Nearest to pope: papal, antipope, pius, boniface, popes, schism, avignon, soissons,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8630 0.0672 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8509 0.0656 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8254 0.0657 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8384 0.0657 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8581 0.0662 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8198 0.0658 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8193 0.0661 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8484 0.0656 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8042 0.0661 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8302 0.0663 sec/batch
# Nearest to not: that, although, but, did, as, to, their, they,
# Nearest to there: are, have, any, many, out, the, all, is,
# Nearest to many: most, are, some, as, there, in, were, larger,
# Nearest to three: two, six, one, eight, zero, five, four, nine,
# Nearest to b: bmod, conformations, aerodrome, manush, smale, transitivity, ltcm, e,
# Nearest to but: not, to, although, it, though, is, in, again,
# Nearest to have: been, in, are, the, there, to, be, that,
# Nearest to american: americans, british, initialized, states, actress, novelist, enquirer, blacks,
# Nearest to hold: asic, wentworth, penrose, migrates, monothelitism, conferred, sinful, bernadotte,
# Nearest to channel: channels, dts, manche, embarrassing, fluctuating, broadcasting, tv, pax,
# Nearest to universe: confers, metabolize, waller, existence, prophetically, hecate, generalise, worlds,
# Nearest to report: memo, foia, personify, newsletter, medlineplus, bloggers, reservists, afghans,
# Nearest to orthodox: orthodoxy, kislev, anastasia, turkish, underbelly, belarus, authenticated, theodosius,
# Nearest to proposed: officially, thanking, affects, lsch, sverdlovsk, willers, mortuary, testable,
# Nearest to issue: declaring, borden, restraining, dissent, aspartate, blocking, forlorn, posed,
# Nearest to pope: papal, antipope, pius, popes, boniface, schism, soissons, innocent,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8830 0.0675 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8419 0.0664 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9257 0.0662 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8963 0.0660 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8801 0.0661 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8202 0.0659 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7624 0.0658 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8451 0.0658 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7292 0.0660 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8560 0.0663 sec/batch
# Nearest to not: that, did, but, although, t, as, would, it,
# Nearest to there: are, have, any, out, many, the, is, to,
# Nearest to many: most, are, some, as, there, were, highly, popular,
# Nearest to three: two, six, zero, eight, one, five, four, nine,
# Nearest to b: manush, economist, d, hairstyle, player, bmod, scalia, hendrick,
# Nearest to but: although, to, though, not, it, that, relied, again,
# Nearest to have: been, in, there, are, has, other, the, although,
# Nearest to american: actress, british, initialized, states, laureate, actor, americans, novelist,
# Nearest to hold: wentworth, asic, penrose, monothelitism, conferred, migrates, bernadotte, sinful,
# Nearest to channel: manche, channels, dts, fluctuating, oppidum, broadcasting, embarrassing, magnetic,
# Nearest to universe: confers, metabolize, waller, existence, hecate, generalise, prophetically, naturalistic,
# Nearest to report: foia, memo, personify, newsletter, interview, medlineplus, floodgates, afghans,
# Nearest to orthodox: orthodoxy, kislev, underbelly, turkish, anastasia, belarus, memeplexes, authenticated,
# Nearest to proposed: thanking, officially, affects, lsch, mortuary, willers, sverdlovsk, bacteria,
# Nearest to issue: borden, declaring, dissent, restraining, aspartate, forlorn, blocking, tahrir,
# Nearest to pope: papal, antipope, pius, popes, boniface, soissons, innocent, avignon,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8099 0.0666 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8345 0.0657 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
